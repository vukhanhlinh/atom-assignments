# %% [markdown]
# <a href="https://colab.research.google.com/github/vukhanhlinh/atom-assignments/blob/main/assignment_3/home_assignment_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HOME ASSIGNMENT #3: SLACK API - TO GSHEET
# **Mục đích của bài Assignment**
# - Lấy thông tin các Users từ Slack của DataCracy (BTC, Mentors và Learners)
# - `**[Optional 1]**` Đưa danh sách Users lên Google Spreadsheet, để theo dõi
# - `**[Optional 2]**` Lấy thông tin Assignment Submission và số Reviews trên `#atom-assignmentnt2` và cập nhật lên Spreadsheet, để theo dõi các học viên đã nộp bài và được review
#
# **Các kiến thức sẽ áp dụng**
# - Ôn lại và luyện tập thêm về concept API (cụ thể sử dụng API Slack)
# - Trích xuất thông tin từ JSON
# - Dùng module gspread để đưa thông tin lên Google Spreadsheet

# %% [markdown]
# ## 0. Load Modules

# %%
import requests #-> Để gọi API
import re #-> Để xử lý data dạng string
from datetime import datetime as dt #-> Để xử lý data dạng datetime
import gspread #-> Để update data lên Google Spreadsheet
from gspread_dataframe import set_with_dataframe #-> Để update data lên Google Spreadsheet
import pandas as pd #-> Để update data dạng bản
import json 
from oauth2client.service_account import ServiceAccountCredentials #-> Để nhập Google Spreadsheet Credentials
import os

# %% [markdown]
# ## 1. Slack API: User List
# * Bạn có thể đọc lại về concept API [HERE](https://anhdang.gitbook.io/datacracy/atom/3-data-tools-2/3.2-spotify-api-and-postman)
# * Assignment này sẽ dùng Slack API để lấy thông tin về Learners và theo dõi các bài tập đã nộp và được review (sau đó cập nhật lên Google Spreadsheet)
# * ===> **NOTICE**: Slack API authorize bằng Bearer Token `xoxb-...-...-...` (Sẽ được cung cấp riêng)
# * Update file `env_variable.json` như trong [Assignment#2](../assignment_2/home_assignment_2.ipynb)
# * ==> Nếu bạn dùng Google Colab, upload file vào Colab ([Hướng dẫn](https://colab.research.google.com/notebooks/io.ipynb))

# %%
# !ls #Liệt kê các file
# Out:
# datacracy-assignment3.json  env_variable.json  sample_data

# %%
with open('env_variable.json', 'r') as j:
    json_data = json.load(j)
    # print(json_data)

# %%
## Load SLACK_BEARER_TOKEN
os.environ['SLACK_BEARER_TOKEN'] = json_data['SLACK_BEARER_TOKEN']

# %%
## Gọi API từ Endpoints (Input - Token được đưa vào Headers)
## Challenge: Thử gọi API này bằng Postman
endpoint = "https://slack.com/api/users.list"
headers = {"Authorization": "Bearer {}".format(os.environ['SLACK_BEARER_TOKEN'])}
response_json = requests.post(endpoint, headers=headers).json() 
user_dat = response_json['members']

# %% [markdown]
# ### TODO #1
# Hoàn tất đoạn code sau

# %%
user_dat #Liệt kê thông tin
# Out:
# [{'color': '757575',
#   'deleted': False,
#   'id': 'USLACKBOT',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': False,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'slackbot',
#   'profile': {'always_active': True,
#    'avatar_hash': 'sv41d8cd98f0',
#    'display_name': 'Slackbot',
#    'display_name_normalized': 'Slackbot',
#    'fields': None,
#    'first_name': 'slackbot',
#    'image_192': 'https://a.slack-edge.com/80588/marketing/img/avatars/slackbot/avatar-slackbot.png',
#    'image_24': 'https://a.slack-edge.com/80588/img/slackbot_24.png',
#    'image_32': 'https://a.slack-edge.com/80588/img/slackbot_32.png',
#    'image_48': 'https://a.slack-edge.com/80588/img/slackbot_48.png',
#    'image_512': 'https://a.slack-edge.com/80588/img/slackbot_512.png',
#    'image_72': 'https://a.slack-edge.com/80588/img/slackbot_72.png',
#    'last_name': '',
#    'phone': '',
#    'real_name': 'Slackbot',
#    'real_name_normalized': 'Slackbot',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Slackbot',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'America/Los_Angeles',
#   'tz_label': 'Pacific Daylight Time',
#   'tz_offset': -25200,
#   'updated': 0},
#  {'color': '4bbe2e',
#   'deleted': False,
#   'id': 'U01AT4T75JB',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'loclexuan26392',
#   'profile': {'avatar_hash': '215adf26bbc2',
#    'display_name': 'Loc Le Xuan',
#    'display_name_normalized': 'Loc Le Xuan',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2020-09-23/1396842133361_215adf26bbc2337f385a_original.jpg',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Loc Le Xuan',
#    'real_name_normalized': 'Loc Le Xuan',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Loc Le Xuan',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1600924572},
#  {'color': 'e7392d',
#   'deleted': False,
#   'id': 'U01AVDY7JET',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'locle.ds',
#   'profile': {'avatar_hash': 'e8ab87f2bc95',
#    'display_name': 'Loc Le Xuan',
#    'display_name_normalized': 'Loc Le Xuan',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2020-09-24/1378029538374_e8ab87f2bc953c34e09c_original.jpg',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Loc Le Xuan',
#    'real_name_normalized': 'Loc Le Xuan',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Loc Le Xuan',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1600943506},
#  {'color': '9f69e7',
#   'deleted': False,
#   'id': 'U01BE2PR6LU',
#   'is_admin': True,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': True,
#   'is_primary_owner': True,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'maianhdang.ftu',
#   'profile': {'avatar_hash': 'gdcf7e1aca86',
#    'display_name': 'MAD',
#    'display_name_normalized': 'MAD',
#    'fields': None,
#    'first_name': 'Đặng',
#    'image_192': 'https://secure.gravatar.com/avatar/dcf7e1aca86cc2adb657e2bd2415352f.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/dcf7e1aca86cc2adb657e2bd2415352f.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/dcf7e1aca86cc2adb657e2bd2415352f.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/dcf7e1aca86cc2adb657e2bd2415352f.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/dcf7e1aca86cc2adb657e2bd2415352f.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/dcf7e1aca86cc2adb657e2bd2415352f.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-72.png',
#    'last_name': 'Huỳnh Mai Anh',
#    'phone': '',
#    'real_name': 'Đặng Huỳnh Mai Anh',
#    'real_name_normalized': 'Dặng Huỳnh Mai Anh',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': 'Technical Contents'},
#   'real_name': 'Đặng Huỳnh Mai Anh',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618595000},
#  {'color': '3c989f',
#   'deleted': False,
#   'id': 'U01C48T7S1J',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'huyenhoang.design',
#   'profile': {'avatar_hash': '8bf84b1c7d5f',
#    'display_name': 'Thanh Huyen Hoang',
#    'display_name_normalized': 'Thanh Huyen Hoang',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2020-10-04/1403202309685_8bf84b1c7d5fd4cffcd7_1024.png',
#    'image_192': 'https://avatars.slack-edge.com/2020-10-04/1403202309685_8bf84b1c7d5fd4cffcd7_192.png',
#    'image_24': 'https://avatars.slack-edge.com/2020-10-04/1403202309685_8bf84b1c7d5fd4cffcd7_24.png',
#    'image_32': 'https://avatars.slack-edge.com/2020-10-04/1403202309685_8bf84b1c7d5fd4cffcd7_32.png',
#    'image_48': 'https://avatars.slack-edge.com/2020-10-04/1403202309685_8bf84b1c7d5fd4cffcd7_48.png',
#    'image_512': 'https://avatars.slack-edge.com/2020-10-04/1403202309685_8bf84b1c7d5fd4cffcd7_512.png',
#    'image_72': 'https://avatars.slack-edge.com/2020-10-04/1403202309685_8bf84b1c7d5fd4cffcd7_72.png',
#    'image_original': 'https://avatars.slack-edge.com/2020-10-04/1403202309685_8bf84b1c7d5fd4cffcd7_original.png',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Thanh Huyen Hoang',
#    'real_name_normalized': 'Thanh Huyen Hoang',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Thanh Huyen Hoang',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Europe/Amsterdam',
#   'tz_label': 'Central European Summer Time',
#   'tz_offset': 7200,
#   'updated': 1601879503},
#  {'color': '674b1b',
#   'deleted': False,
#   'id': 'U01CMTYB7EU',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': False,
#   'is_invited_user': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'dr.tringuyenzmc',
#   'profile': {'avatar_hash': 'g4449889519e',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/4449889519ebda3244ad83efc06d00b8.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0021-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/4449889519ebda3244ad83efc06d00b8.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0021-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/4449889519ebda3244ad83efc06d00b8.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0021-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/4449889519ebda3244ad83efc06d00b8.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0021-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/4449889519ebda3244ad83efc06d00b8.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0021-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/4449889519ebda3244ad83efc06d00b8.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0021-72.png',
#    'phone': '',
#    'real_name': 'Dr Tringuyenzmc',
#    'real_name_normalized': 'Dr Tringuyenzmc',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Dr Tringuyenzmc',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1601867824},
#  {'color': 'e96699',
#   'deleted': False,
#   'id': 'U01GQR2FE93',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'khanguyenwk',
#   'profile': {'avatar_hash': 'aa9c4160c7d5',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'first_name': 'Kha',
#    'image_1024': 'https://avatars.slack-edge.com/2020-12-17/1581695197602_aa9c4160c7d52924d539_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2020-12-17/1581695197602_aa9c4160c7d52924d539_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2020-12-17/1581695197602_aa9c4160c7d52924d539_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2020-12-17/1581695197602_aa9c4160c7d52924d539_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2020-12-17/1581695197602_aa9c4160c7d52924d539_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2020-12-17/1581695197602_aa9c4160c7d52924d539_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2020-12-17/1581695197602_aa9c4160c7d52924d539_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2020-12-17/1581695197602_aa9c4160c7d52924d539_original.jpg',
#    'is_custom_image': True,
#    'last_name': 'Nguyen',
#    'phone': '',
#    'real_name': 'Kha Nguyen',
#    'real_name_normalized': 'Kha Nguyen',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Kha Nguyen',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618627784},
#  {'color': 'e0a729',
#   'deleted': False,
#   'id': 'U01HARCHNKU',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'linhphan',
#   'profile': {'avatar_hash': 'ge0747f5df59',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/e0747f5df598b8d4d0852d49a735405b.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0005-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/e0747f5df598b8d4d0852d49a735405b.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0005-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/e0747f5df598b8d4d0852d49a735405b.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0005-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/e0747f5df598b8d4d0852d49a735405b.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0005-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/e0747f5df598b8d4d0852d49a735405b.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0005-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/e0747f5df598b8d4d0852d49a735405b.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0005-72.png',
#    'phone': '',
#    'real_name': 'Phan Linh',
#    'real_name_normalized': 'Phan Linh',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Phan Linh',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1608459687},
#  {'color': '5b89d5',
#   'deleted': False,
#   'id': 'U01JQ5TUP0B',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': False,
#   'is_invited_user': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'tt.thuchuyen',
#   'profile': {'avatar_hash': 'g05ec3d7e8ad',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/05ec3d7e8adf756aa41e08ff4562dd99.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/05ec3d7e8adf756aa41e08ff4562dd99.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/05ec3d7e8adf756aa41e08ff4562dd99.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/05ec3d7e8adf756aa41e08ff4562dd99.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/05ec3d7e8adf756aa41e08ff4562dd99.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/05ec3d7e8adf756aa41e08ff4562dd99.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0014-72.png',
#    'phone': '',
#    'real_name': 'Tt Thuchuyen',
#    'real_name_normalized': 'Tt Thuchuyen',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Tt Thuchuyen',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1610614016},
#  {'color': '2b6836',
#   'deleted': False,
#   'id': 'U01JQ5U1RPV',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'thuongthuong.dv',
#   'profile': {'avatar_hash': 'ecc0c90a7ed9',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'first_name': 'Thuong',
#    'image_1024': 'https://avatars.slack-edge.com/2021-01-14/1645503907652_ecc0c90a7ed914393758_1024.png',
#    'image_192': 'https://avatars.slack-edge.com/2021-01-14/1645503907652_ecc0c90a7ed914393758_192.png',
#    'image_24': 'https://avatars.slack-edge.com/2021-01-14/1645503907652_ecc0c90a7ed914393758_24.png',
#    'image_32': 'https://avatars.slack-edge.com/2021-01-14/1645503907652_ecc0c90a7ed914393758_32.png',
#    'image_48': 'https://avatars.slack-edge.com/2021-01-14/1645503907652_ecc0c90a7ed914393758_48.png',
#    'image_512': 'https://avatars.slack-edge.com/2021-01-14/1645503907652_ecc0c90a7ed914393758_512.png',
#    'image_72': 'https://avatars.slack-edge.com/2021-01-14/1645503907652_ecc0c90a7ed914393758_72.png',
#    'image_original': 'https://avatars.slack-edge.com/2021-01-14/1645503907652_ecc0c90a7ed914393758_original.png',
#    'is_custom_image': True,
#    'last_name': 'Do',
#    'phone': '',
#    'real_name': 'Thuong Do',
#    'real_name_normalized': 'Thuong Do',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Thuong Do',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1611925712},
#  {'color': '99a949',
#   'deleted': False,
#   'id': 'U01JQ5U4ADR',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': False,
#   'is_invited_user': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'duongliengia',
#   'profile': {'avatar_hash': 'gb623ba4f681',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/b623ba4f681ea611721ad91f4ed9b63a.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0019-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/b623ba4f681ea611721ad91f4ed9b63a.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0019-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/b623ba4f681ea611721ad91f4ed9b63a.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0019-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/b623ba4f681ea611721ad91f4ed9b63a.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0019-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/b623ba4f681ea611721ad91f4ed9b63a.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0019-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/b623ba4f681ea611721ad91f4ed9b63a.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0019-72.png',
#    'phone': '',
#    'real_name': 'duongliengia',
#    'real_name_normalized': 'duongliengia',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'duongliengia',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1610614021},
#  {'color': '684b6c',
#   'deleted': False,
#   'id': 'U01KDQJ9FCG',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'phanthuylinh8396',
#   'profile': {'avatar_hash': 'g01fde7d57e7',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/01fde7d57e76e7aaba8a3437164ac888.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/01fde7d57e76e7aaba8a3437164ac888.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/01fde7d57e76e7aaba8a3437164ac888.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/01fde7d57e76e7aaba8a3437164ac888.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/01fde7d57e76e7aaba8a3437164ac888.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/01fde7d57e76e7aaba8a3437164ac888.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-72.png',
#    'phone': '',
#    'real_name': 'Phan Linh',
#    'real_name_normalized': 'Phan Linh',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Phan Linh',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1619197336},
#  {'color': '3c8c69',
#   'deleted': False,
#   'id': 'U01U6JM6LEB',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'hoangquocviet.208',
#   'profile': {'avatar_hash': 'df69a645790b',
#    'display_name': 'Viet Hoang',
#    'display_name_normalized': 'Viet Hoang',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-16/1986020941905_df69a645790bc323b745_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-16/1986020941905_df69a645790bc323b745_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-16/1986020941905_df69a645790bc323b745_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-16/1986020941905_df69a645790bc323b745_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-16/1986020941905_df69a645790bc323b745_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-16/1986020941905_df69a645790bc323b745_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-16/1986020941905_df69a645790bc323b745_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-16/1986020941905_df69a645790bc323b745_original.jpg',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Viet Hoang',
#    'real_name_normalized': 'Viet Hoang',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Viet Hoang',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618626988},
#  {'color': '965d1b',
#   'deleted': False,
#   'id': 'U01U6JQB695',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'thgiang.phan',
#   'profile': {'avatar_hash': 'g23f9856d170',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/23f9856d170c91ca68d1c8fa86a97c48.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/23f9856d170c91ca68d1c8fa86a97c48.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/23f9856d170c91ca68d1c8fa86a97c48.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/23f9856d170c91ca68d1c8fa86a97c48.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/23f9856d170c91ca68d1c8fa86a97c48.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/23f9856d170c91ca68d1c8fa86a97c48.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0016-72.png',
#    'phone': '',
#    'real_name': 'Giang Phan',
#    'real_name_normalized': 'Giang Phan',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Giang Phan',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618627292},
#  {'color': '73769d',
#   'deleted': False,
#   'id': 'U01U8CAMGB1',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'huyenngoc2017',
#   'profile': {'avatar_hash': 'dc5c476bf9cc',
#    'display_name': 'Ngoc Huyen',
#    'display_name_normalized': 'Ngoc Huyen',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-18/1960418749751_dc5c476bf9ccb6b0d883_1024.png',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-18/1960418749751_dc5c476bf9ccb6b0d883_192.png',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-18/1960418749751_dc5c476bf9ccb6b0d883_24.png',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-18/1960418749751_dc5c476bf9ccb6b0d883_32.png',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-18/1960418749751_dc5c476bf9ccb6b0d883_48.png',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-18/1960418749751_dc5c476bf9ccb6b0d883_512.png',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-18/1960418749751_dc5c476bf9ccb6b0d883_72.png',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-18/1960418749751_dc5c476bf9ccb6b0d883_original.png',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Ngoc Huyen',
#    'real_name_normalized': 'Ngoc Huyen',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Ngoc Huyen',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618794840},
#  {'color': 'c386df',
#   'deleted': False,
#   'id': 'U01UEJFMUSJ',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'nhuhai03',
#   'profile': {'avatar_hash': '9dacf9ff9907',
#    'display_name': 'Duong Nhu Hai',
#    'display_name_normalized': 'Duong Nhu Hai',
#    'fields': None,
#    'first_name': 'Duong',
#    'image_1024': 'https://avatars.slack-edge.com/2021-05-15/2068605242210_9dacf9ff990779effc5e_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2021-05-15/2068605242210_9dacf9ff990779effc5e_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2021-05-15/2068605242210_9dacf9ff990779effc5e_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2021-05-15/2068605242210_9dacf9ff990779effc5e_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2021-05-15/2068605242210_9dacf9ff990779effc5e_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2021-05-15/2068605242210_9dacf9ff990779effc5e_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2021-05-15/2068605242210_9dacf9ff990779effc5e_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2021-05-15/2068605242210_9dacf9ff990779effc5e_original.jpg',
#    'is_custom_image': True,
#    'last_name': 'Nhu Hai',
#    'phone': '',
#    'real_name': 'Duong Nhu Hai',
#    'real_name_normalized': 'Duong Nhu Hai',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Duong Nhu Hai',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1621074610},
#  {'color': '50a0cf',
#   'deleted': False,
#   'id': 'U01UEJG8KHU',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'trangnguyen.n3t',
#   'profile': {'avatar_hash': '101ae729af10',
#    'display_name': 'Trang Nguyễn',
#    'display_name_normalized': 'Trang Nguyễn',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-16/1986019801457_101ae729af10f158c82f_1024.png',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-16/1986019801457_101ae729af10f158c82f_192.png',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-16/1986019801457_101ae729af10f158c82f_24.png',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-16/1986019801457_101ae729af10f158c82f_32.png',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-16/1986019801457_101ae729af10f158c82f_48.png',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-16/1986019801457_101ae729af10f158c82f_512.png',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-16/1986019801457_101ae729af10f158c82f_72.png',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-16/1986019801457_101ae729af10f158c82f_original.png',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Trang Nguyễn',
#    'real_name_normalized': 'Trang Nguyễn',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Trang Nguyễn',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618626883},
#  {'color': 'aba727',
#   'deleted': False,
#   'id': 'U01UEJKV3PG',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'nhduyen1995',
#   'profile': {'avatar_hash': '833653d7d0b6',
#    'display_name': 'Duyên Nguyễn Hồng',
#    'display_name_normalized': 'Duyen Nguyễn Hồng',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-16/1970331624965_833653d7d0b658c53ca1_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-16/1970331624965_833653d7d0b658c53ca1_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-16/1970331624965_833653d7d0b658c53ca1_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-16/1970331624965_833653d7d0b658c53ca1_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-16/1970331624965_833653d7d0b658c53ca1_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-16/1970331624965_833653d7d0b658c53ca1_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-16/1970331624965_833653d7d0b658c53ca1_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-16/1970331624965_833653d7d0b658c53ca1_original.jpg',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Duyên Nguyễn Hồng',
#    'real_name_normalized': 'Duyen Nguyễn Hồng',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Duyên Nguyễn Hồng',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618627235},
#  {'color': '9d8eee',
#   'deleted': False,
#   'id': 'U01UFKDG79U',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'hanhdinh.201099',
#   'profile': {'avatar_hash': '68872c25cd0d',
#    'display_name': 'Mỹ Hạnh Đinh Thị',
#    'display_name_normalized': 'Mỹ Hạnh Dinh Thị',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-17/1967659560038_68872c25cd0d578c8679_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-17/1967659560038_68872c25cd0d578c8679_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-17/1967659560038_68872c25cd0d578c8679_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-17/1967659560038_68872c25cd0d578c8679_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-17/1967659560038_68872c25cd0d578c8679_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-17/1967659560038_68872c25cd0d578c8679_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-17/1967659560038_68872c25cd0d578c8679_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-17/1967659560038_68872c25cd0d578c8679_original.jpg',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Mỹ Hạnh Đinh Thị',
#    'real_name_normalized': 'Mỹ Hạnh Dinh Thị',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Mỹ Hạnh Đinh Thị',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618728242},
#  {'color': '8469bc',
#   'deleted': False,
#   'id': 'U01UFTS0UGN',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': True,
#   'is_email_confirmed': False,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'googledrive',
#   'profile': {'always_active': True,
#    'api_app_id': 'A6NL8MJ6Q',
#    'avatar_hash': '665434988a7e',
#    'bot_id': 'B01UNTDPPCK',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-18/1974720937314_665434988a7e8995f10d_1024.png',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-18/1974720937314_665434988a7e8995f10d_192.png',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-18/1974720937314_665434988a7e8995f10d_24.png',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-18/1974720937314_665434988a7e8995f10d_32.png',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-18/1974720937314_665434988a7e8995f10d_48.png',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-18/1974720937314_665434988a7e8995f10d_512.png',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-18/1974720937314_665434988a7e8995f10d_72.png',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-18/1974720937314_665434988a7e8995f10d_original.png',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Google Drive',
#    'real_name_normalized': 'Google Drive',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Google Drive',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'America/Los_Angeles',
#   'tz_label': 'Pacific Daylight Time',
#   'tz_offset': -25200,
#   'updated': 1618756322},
#  {'color': 'df3dc0',
#   'deleted': False,
#   'id': 'U01UJ9LG5U5',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'danhpcv',
#   'profile': {'avatar_hash': '12fb110c15fb',
#    'display_name': 'Danh Phan',
#    'display_name_normalized': 'Danh Phan',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-16/1970326574005_12fb110c15fb55fa8c23_1024.png',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-16/1970326574005_12fb110c15fb55fa8c23_192.png',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-16/1970326574005_12fb110c15fb55fa8c23_24.png',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-16/1970326574005_12fb110c15fb55fa8c23_32.png',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-16/1970326574005_12fb110c15fb55fa8c23_48.png',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-16/1970326574005_12fb110c15fb55fa8c23_512.png',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-16/1970326574005_12fb110c15fb55fa8c23_72.png',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-16/1970326574005_12fb110c15fb55fa8c23_original.png',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Danh Phan',
#    'real_name_normalized': 'Danh Phan',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Danh Phan',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618626755},
#  {'color': '9e3997',
#   'deleted': False,
#   'id': 'U01UJ9M3P1T',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'cnhhoang850',
#   'profile': {'avatar_hash': 'ebf963fb1868',
#    'display_name': 'Cao Nguyen Huy Hoang',
#    'display_name_normalized': 'Cao Nguyen Huy Hoang',
#    'fields': None,
#    'first_name': 'Cao',
#    'image_1024': 'https://avatars.slack-edge.com/2021-05-19/2066912101127_ebf963fb1868df93a663_1024.png',
#    'image_192': 'https://avatars.slack-edge.com/2021-05-19/2066912101127_ebf963fb1868df93a663_192.png',
#    'image_24': 'https://avatars.slack-edge.com/2021-05-19/2066912101127_ebf963fb1868df93a663_24.png',
#    'image_32': 'https://avatars.slack-edge.com/2021-05-19/2066912101127_ebf963fb1868df93a663_32.png',
#    'image_48': 'https://avatars.slack-edge.com/2021-05-19/2066912101127_ebf963fb1868df93a663_48.png',
#    'image_512': 'https://avatars.slack-edge.com/2021-05-19/2066912101127_ebf963fb1868df93a663_512.png',
#    'image_72': 'https://avatars.slack-edge.com/2021-05-19/2066912101127_ebf963fb1868df93a663_72.png',
#    'image_original': 'https://avatars.slack-edge.com/2021-05-19/2066912101127_ebf963fb1868df93a663_original.png',
#    'is_custom_image': True,
#    'last_name': 'Nguyen Huy Hoang',
#    'phone': '',
#    'real_name': 'Cao Nguyen Huy Hoang',
#    'real_name_normalized': 'Cao Nguyen Huy Hoang',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Cao Nguyen Huy Hoang',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1621434759},
#  {'color': '53b759',
#   'deleted': False,
#   'id': 'U01UJ9M5TU5',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'minhnguyentk95',
#   'profile': {'avatar_hash': '19f44aac258f',
#    'display_name': 'Minh Nguyen',
#    'display_name_normalized': 'Minh Nguyen',
#    'fields': None,
#    'first_name': 'Nguyen',
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-24/1996391683970_19f44aac258f3bcbe6c3_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-24/1996391683970_19f44aac258f3bcbe6c3_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-24/1996391683970_19f44aac258f3bcbe6c3_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-24/1996391683970_19f44aac258f3bcbe6c3_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-24/1996391683970_19f44aac258f3bcbe6c3_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-24/1996391683970_19f44aac258f3bcbe6c3_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-24/1996391683970_19f44aac258f3bcbe6c3_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-24/1996391683970_19f44aac258f3bcbe6c3_original.jpg',
#    'is_custom_image': True,
#    'last_name': 'Thi Kim Minh',
#    'phone': '0703988802',
#    'real_name': 'Nguyen Thi Kim Minh',
#    'real_name_normalized': 'Nguyen Thi Kim Minh',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Nguyen Thi Kim Minh',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1619200975},
#  {'color': 'd1707d',
#   'deleted': False,
#   'id': 'U01UJ9MUADT',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'lovelylife.158',
#   'profile': {'avatar_hash': '69d858a7de64',
#    'display_name': 'Thu Trang',
#    'display_name_normalized': 'Thu Trang',
#    'fields': None,
#    'first_name': 'Nguyễn',
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-17/1986438478433_69d858a7de64c583d4c8_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-17/1986438478433_69d858a7de64c583d4c8_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-17/1986438478433_69d858a7de64c583d4c8_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-17/1986438478433_69d858a7de64c583d4c8_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-17/1986438478433_69d858a7de64c583d4c8_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-17/1986438478433_69d858a7de64c583d4c8_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-17/1986438478433_69d858a7de64c583d4c8_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-17/1986438478433_69d858a7de64c583d4c8_original.jpg',
#    'is_custom_image': True,
#    'last_name': 'Thị Thu Trang',
#    'phone': '',
#    'real_name': 'Nguyễn Thị Thu Trang',
#    'real_name_normalized': 'Nguyễn Thị Thu Trang',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': 'Learner'},
#   'real_name': 'Nguyễn Thị Thu Trang',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1622125032},
#  {'color': 'de5f24',
#   'deleted': False,
#   'id': 'U01UJ9NKX8D',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'lienanhhuong96',
#   'profile': {'avatar_hash': '457571373b2a',
#    'display_name': 'Lien Anh Trinh',
#    'display_name_normalized': 'Lien Anh Trinh',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-16/1958632850647_457571373b2a9572061c_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-16/1958632850647_457571373b2a9572061c_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-16/1958632850647_457571373b2a9572061c_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-16/1958632850647_457571373b2a9572061c_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-16/1958632850647_457571373b2a9572061c_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-16/1958632850647_457571373b2a9572061c_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-16/1958632850647_457571373b2a9572061c_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-16/1958632850647_457571373b2a9572061c_original.jpg',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Lien Anh Trinh',
#    'real_name_normalized': 'Lien Anh Trinh',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Lien Anh Trinh',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618626952},
#  {'color': '827327',
#   'deleted': False,
#   'id': 'U01UJ9P1S3X',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'thao',
#   'profile': {'avatar_hash': 'a170c78442a9',
#    'display_name': 'Thao Le',
#    'display_name_normalized': 'Thao Le',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-16/1973617290371_a170c78442a99a206aa4_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-16/1973617290371_a170c78442a99a206aa4_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-16/1973617290371_a170c78442a99a206aa4_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-16/1973617290371_a170c78442a99a206aa4_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-16/1973617290371_a170c78442a99a206aa4_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-16/1973617290371_a170c78442a99a206aa4_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-16/1973617290371_a170c78442a99a206aa4_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-16/1973617290371_a170c78442a99a206aa4_original.jpg',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Thao Le',
#    'real_name_normalized': 'Thao Le',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Thao Le',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618626988},
#  {'color': '84b22f',
#   'deleted': False,
#   'id': 'U01UJ9PA0MB',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'doithihong92',
#   'profile': {'avatar_hash': '7dcd2ccb60e2',
#    'display_name': 'Hồng Đới',
#    'display_name_normalized': 'Hồng Dới',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-04-16/1966629716758_7dcd2ccb60e2192924a1_1024.jpg',
#    'image_192': 'https://avatars.slack-edge.com/2021-04-16/1966629716758_7dcd2ccb60e2192924a1_192.jpg',
#    'image_24': 'https://avatars.slack-edge.com/2021-04-16/1966629716758_7dcd2ccb60e2192924a1_24.jpg',
#    'image_32': 'https://avatars.slack-edge.com/2021-04-16/1966629716758_7dcd2ccb60e2192924a1_32.jpg',
#    'image_48': 'https://avatars.slack-edge.com/2021-04-16/1966629716758_7dcd2ccb60e2192924a1_48.jpg',
#    'image_512': 'https://avatars.slack-edge.com/2021-04-16/1966629716758_7dcd2ccb60e2192924a1_512.jpg',
#    'image_72': 'https://avatars.slack-edge.com/2021-04-16/1966629716758_7dcd2ccb60e2192924a1_72.jpg',
#    'image_original': 'https://avatars.slack-edge.com/2021-04-16/1966629716758_7dcd2ccb60e2192924a1_original.jpg',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'Hồng Đới',
#    'real_name_normalized': 'Hồng Dới',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Hồng Đới',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1618627015},
#  {'color': '4ec0d6',
#   'deleted': False,
#   'id': 'U01UJ9PRT5K',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'hieulam1312',
#   'profile': {'avatar_hash': 'b09bf566c251',
#    'display_name': 'Hiếu',
# ...
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'team_id': 'T01B7SGGMLJ',
#   'updated': 1621856607},
#  {'color': '684b6c',
#   'deleted': False,
#   'id': 'U0226MQ73MJ',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': True,
#   'is_email_confirmed': False,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'mad',
#   'profile': {'always_active': False,
#    'api_app_id': 'A0220GDHWJW',
#    'avatar_hash': 'ga147329c4ca',
#    'bot_id': 'B022QB4TL9W',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'first_name': 'MAD',
#    'image_192': 'https://secure.gravatar.com/avatar/a147329c4ca6735286d053d06784665c.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0001-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/a147329c4ca6735286d053d06784665c.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0001-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/a147329c4ca6735286d053d06784665c.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0001-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/a147329c4ca6735286d053d06784665c.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0001-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/a147329c4ca6735286d053d06784665c.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0001-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/a147329c4ca6735286d053d06784665c.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0001-72.png',
#    'last_name': '',
#    'phone': '',
#    'real_name': 'MAD',
#    'real_name_normalized': 'MAD',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'MAD',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'America/Los_Angeles',
#   'tz_label': 'Pacific Daylight Time',
#   'tz_offset': -25200,
#   'updated': 1622694573},
#  {'deleted': True,
#   'id': 'U022BEV3FEW',
#   'is_app_user': False,
#   'is_bot': True,
#   'name': 'convhist',
#   'profile': {'always_active': False,
#    'api_app_id': 'A022Q3GUJTB',
#    'avatar_hash': 'ga71d9b3bda0',
#    'bot_id': 'B022BM39LSF',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'first_name': 'conv.hist',
#    'image_192': 'https://secure.gravatar.com/avatar/a71d9b3bda0aecbd692b6eb0de33f162.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0002-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/a71d9b3bda0aecbd692b6eb0de33f162.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0002-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/a71d9b3bda0aecbd692b6eb0de33f162.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0002-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/a71d9b3bda0aecbd692b6eb0de33f162.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0002-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/a71d9b3bda0aecbd692b6eb0de33f162.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0002-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/a71d9b3bda0aecbd692b6eb0de33f162.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0002-72.png',
#    'last_name': '',
#    'phone': '',
#    'real_name': 'conv.hist',
#    'real_name_normalized': 'conv.hist',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'team_id': 'T01B7SGGMLJ',
#   'updated': 1621856713},
#  {'deleted': True,
#   'id': 'U022J0SQAMQ',
#   'is_app_user': False,
#   'is_bot': True,
#   'name': 'abc',
#   'profile': {'always_active': False,
#    'api_app_id': 'A022B6B3F8W',
#    'avatar_hash': 'gc61c18c89c7',
#    'bot_id': 'B022B7ANQES',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/c61c18c89c7377a9e2da92cae356da39.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/c61c18c89c7377a9e2da92cae356da39.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/c61c18c89c7377a9e2da92cae356da39.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/c61c18c89c7377a9e2da92cae356da39.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/c61c18c89c7377a9e2da92cae356da39.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/c61c18c89c7377a9e2da92cae356da39.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-72.png',
#    'phone': '',
#    'real_name': 'abc',
#    'real_name_normalized': 'abc',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'team_id': 'T01B7SGGMLJ',
#   'updated': 1621856631},
#  {'deleted': True,
#   'id': 'U022R4885AN',
#   'is_app_user': False,
#   'is_bot': True,
#   'name': '78',
#   'profile': {'always_active': False,
#    'api_app_id': 'A023ETPS7SL',
#    'avatar_hash': 'gd082bd59567',
#    'bot_id': 'B022RAGK81H',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/d082bd595679aa34ea6a9f759c743664.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0018-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/d082bd595679aa34ea6a9f759c743664.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0018-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/d082bd595679aa34ea6a9f759c743664.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0018-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/d082bd595679aa34ea6a9f759c743664.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0018-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/d082bd595679aa34ea6a9f759c743664.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0018-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/d082bd595679aa34ea6a9f759c743664.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0018-72.png',
#    'phone': '',
#    'real_name': '78',
#    'real_name_normalized': '78',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'team_id': 'T01B7SGGMLJ',
#   'updated': 1621856620},
#  {'color': 'd58247',
#   'deleted': False,
#   'id': 'U0233KHLM2M',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': False,
#   'is_invited_user': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'vuthanhdat.contact',
#   'profile': {'avatar_hash': 'g72ade5f0a21',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/72ade5f0a2147dfa9516ec249642979f.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0007-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/72ade5f0a2147dfa9516ec249642979f.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0007-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/72ade5f0a2147dfa9516ec249642979f.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0007-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/72ade5f0a2147dfa9516ec249642979f.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0007-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/72ade5f0a2147dfa9516ec249642979f.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0007-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/72ade5f0a2147dfa9516ec249642979f.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0007-72.png',
#    'phone': '',
#    'real_name': 'Vuthanhdat Contact',
#    'real_name_normalized': 'Vuthanhdat Contact',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'Vuthanhdat Contact',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1621649389},
#  {'deleted': True,
#   'id': 'U023E0BAHQ8',
#   'is_app_user': False,
#   'is_bot': True,
#   'name': 'testgettoken',
#   'profile': {'always_active': True,
#    'api_app_id': 'A022HBW1Z9U',
#    'avatar_hash': 'gc28c6476803',
#    'bot_id': 'B022WAYRETW',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'first_name': 'test.gettoken',
#    'image_192': 'https://secure.gravatar.com/avatar/c28c647680342591290d4dca604303d5.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0020-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/c28c647680342591290d4dca604303d5.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0020-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/c28c647680342591290d4dca604303d5.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0020-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/c28c647680342591290d4dca604303d5.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0020-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/c28c647680342591290d4dca604303d5.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0020-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/c28c647680342591290d4dca604303d5.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0020-72.png',
#    'last_name': '',
#    'phone': '',
#    'real_name': 'test.gettoken',
#    'real_name_normalized': 'test.gettoken',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'team_id': 'T01B7SGGMLJ',
#   'updated': 1621856654},
#  {'deleted': True,
#   'id': 'U023G7HDUL8',
#   'is_app_user': False,
#   'is_bot': True,
#   'name': 'ass4',
#   'profile': {'always_active': False,
#    'api_app_id': 'A022SD34Z18',
#    'avatar_hash': 'g9a7abdbdcd7',
#    'bot_id': 'B022SDBMGQ2',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'first_name': 'Ass4',
#    'image_192': 'https://secure.gravatar.com/avatar/9a7abdbdcd72745e71d5c81f13292e7f.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0024-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/9a7abdbdcd72745e71d5c81f13292e7f.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0024-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/9a7abdbdcd72745e71d5c81f13292e7f.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0024-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/9a7abdbdcd72745e71d5c81f13292e7f.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0024-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/9a7abdbdcd72745e71d5c81f13292e7f.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0024-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/9a7abdbdcd72745e71d5c81f13292e7f.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0024-72.png',
#    'last_name': '',
#    'phone': '',
#    'real_name': 'Ass4',
#    'real_name_normalized': 'Ass4',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'team_id': 'T01B7SGGMLJ',
#   'updated': 1621856695},
#  {'color': 'db3150',
#   'deleted': False,
#   'id': 'U024A4CRKQC',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'contact.datacracy',
#   'profile': {'avatar_hash': '6dc03b58e16a',
#    'display_name': 'DATAcracy',
#    'display_name_normalized': 'DATAcracy',
#    'fields': None,
#    'image_1024': 'https://avatars.slack-edge.com/2021-06-04/2140197536691_6dc03b58e16a5ca290dd_1024.png',
#    'image_192': 'https://avatars.slack-edge.com/2021-06-04/2140197536691_6dc03b58e16a5ca290dd_192.png',
#    'image_24': 'https://avatars.slack-edge.com/2021-06-04/2140197536691_6dc03b58e16a5ca290dd_24.png',
#    'image_32': 'https://avatars.slack-edge.com/2021-06-04/2140197536691_6dc03b58e16a5ca290dd_32.png',
#    'image_48': 'https://avatars.slack-edge.com/2021-06-04/2140197536691_6dc03b58e16a5ca290dd_48.png',
#    'image_512': 'https://avatars.slack-edge.com/2021-06-04/2140197536691_6dc03b58e16a5ca290dd_512.png',
#    'image_72': 'https://avatars.slack-edge.com/2021-06-04/2140197536691_6dc03b58e16a5ca290dd_72.png',
#    'image_original': 'https://avatars.slack-edge.com/2021-06-04/2140197536691_6dc03b58e16a5ca290dd_original.png',
#    'is_custom_image': True,
#    'phone': '',
#    'real_name': 'DATAcracy',
#    'real_name_normalized': 'DATAcracy',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'DATAcracy',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1622859962},
#  {'color': '235e5b',
#   'deleted': False,
#   'id': 'U024HQ60KHP',
#   'is_admin': False,
#   'is_app_user': False,
#   'is_bot': False,
#   'is_email_confirmed': False,
#   'is_invited_user': True,
#   'is_owner': False,
#   'is_primary_owner': False,
#   'is_restricted': False,
#   'is_ultra_restricted': False,
#   'name': 'vhaitran1994',
#   'profile': {'avatar_hash': 'g1560e082fda',
#    'display_name': '',
#    'display_name_normalized': '',
#    'fields': None,
#    'image_192': 'https://secure.gravatar.com/avatar/1560e082fdaad63e60af3950751a320f.jpg?s=192&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0026-192.png',
#    'image_24': 'https://secure.gravatar.com/avatar/1560e082fdaad63e60af3950751a320f.jpg?s=24&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0026-24.png',
#    'image_32': 'https://secure.gravatar.com/avatar/1560e082fdaad63e60af3950751a320f.jpg?s=32&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0026-32.png',
#    'image_48': 'https://secure.gravatar.com/avatar/1560e082fdaad63e60af3950751a320f.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0026-48.png',
#    'image_512': 'https://secure.gravatar.com/avatar/1560e082fdaad63e60af3950751a320f.jpg?s=512&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0026-512.png',
#    'image_72': 'https://secure.gravatar.com/avatar/1560e082fdaad63e60af3950751a320f.jpg?s=72&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0026-72.png',
#    'phone': '',
#    'real_name': 'vhaitran1994',
#    'real_name_normalized': 'vhaitran1994',
#    'skype': '',
#    'status_emoji': '',
#    'status_expiration': 0,
#    'status_text': '',
#    'status_text_canonical': '',
#    'team': 'T01B7SGGMLJ',
#    'title': ''},
#   'real_name': 'vhaitran1994',
#   'team_id': 'T01B7SGGMLJ',
#   'tz': 'Asia/Bangkok',
#   'tz_label': 'Indochina Time',
#   'tz_offset': 25200,
#   'updated': 1622974328}]

# %%
## Loop qua JSON file và extract các thông tin quan trọng (id, name, display_name, real_name_normalized, title, phone, is_bot)
## Hint: Bạn có thể dùng Postman hoặc in user_dat JSON để xem cấu trúc (schema), dùng Ctrl+F để tìm các keys
#        (id, name, display_name, real_name_normalized, title, phone, is_bot)
user_dict = {'user_id':[], 'name':[], 'display_name':[],'real_name':[],'title':[],'phone':[],'is_bot':[]}
for i in range(len(user_dat)):
  user_dict['user_id'].append(user_dat[i]['id'])
  user_dict['name'].append(user_dat[i]['name'])
  user_dict['display_name'].append(user_dat[i]['profile']['display_name'])
  user_dict['real_name'].append(user_dat[i]['profile']['real_name_normalized'])
  user_dict['title'].append(user_dat[i]['profile']['title'])
  user_dict['phone'].append(user_dat[i]['profile']['phone'])
  user_dict['is_bot'].append(user_dat[i]['is_bot'])

# %%
user_df = pd.DataFrame(user_dict) ## Dùng pandas để convert dictionaries thành bảng
user_df.head(5) ## Chỉ in 5 dòng đầu (chủ yếu để xem cấu trúc)
# Out:
#        user_id               name  ... phone is_bot
# 0    USLACKBOT           slackbot  ...        False
# 1  U01AT4T75JB     loclexuan26392  ...        False
# 2  U01AVDY7JET           locle.ds  ...        False
# 3  U01BE2PR6LU     maianhdang.ftu  ...        False
# 4  U01C48T7S1J  huyenhoang.design  ...        False
#
# [5 rows x 7 columns]

# %%
user_df[user_df.display_name == 'MAD'] ## Lọc thông tin của MAD, trên DataFrame (bạn có thể Google thêm)
# Out:
#        user_id            name display_name  ...               title phone is_bot
# 3  U01BE2PR6LU  maianhdang.ftu          MAD  ...  Technical Contents        False
#
# [1 rows x 7 columns]

# %% [markdown]
# -------------- HẾT PHẦN BẮT BUỘC ---------------------

# %% [markdown]
# ## Option 1: Update data => Google SpreadSheet

# %% [markdown]
# ### TODO#2
# Tạo service account (output là file json), file này để cho phép ta access vào Google Spreadsheet:
#
# 1. Làm theo hướng dẫn: [Google Create a Service Account](https://support.google.com/a/answer/7378726?hl=en)
# ![google_service_account](https://github.com/vukhanhlinh/atom-assignments/blob/main/img/google_service_account.png?raw=1)
# 2. Lưu file JSON (chứa credential về máy)
# ![gservice_acc_json](https://github.com/vukhanhlinh/atom-assignments/blob/main/img/gservice_acc_json.png?raw=1)
# 3. Nhớ Enable [Google Drive API](https://console.cloud.google.com/marketplace/product/google/drive.googleapis.com?q=search&referrer=search&project=quickstart-313303) (Nếu bạn chạy code báo lỗi chưa enable API thì vào link trong phần lỗi để Enable, sau khi kích hoạt có thể cần vài phút để chạy được)
# ![enable_api](https://github.com/vukhanhlinh/atom-assignments/blob/main/img/enable_api.png?raw=1)
# * ==> Upload file Gsheet Credential JSON nếu bạn dùng Colab
# * ==> Nếu bạn để key trong repo git, **NHỚ** để file json vào `.gitignore` để không bị leaked key)

# %%
# !ls
# Out:
# datacracy-assignment3.json  env_variable.json  sample_data

# %%
## Authorize bằng JSON
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name('datacracy-assignment3.json', scope)
gc = gspread.authorize(credentials)
print("DONE!")
# Out:
# DONE!

# %% [markdown]
# **Tạo Spreadsheet**
#
# 1. Tạo Spreadsheet trên google
# 2. Invite account trong `client_email` (file JSON Gsheet Credential bên trên) vào Spreadsheet (quyền Editor)
# ![enable_api](https://github.com/vukhanhlinh/atom-assignments/blob/main/img/enable_api.png?raw=1)
# 3. Lấy `SPREADSHEET_KEY` (nằm trong chính URL của Spreadhstee): `https://docs.google.com/spreadsheets/d/<SPREADSHEET_KEY>/edit#gid=0`
#
# ![add_gsheet](https://github.com/vukhanhlinh/atom-assignments/blob/main/img/add_gsheet.png?raw=1)

# %%
# ACCES GOOGLE SHEET
sheet_index_no = 0
spreadsheet_key = '1hNprbtIOKbtyQ7rsG7Ewy566QxlwJfnVxW9QBt38cWQ' # input SPREADSHEET_KEY HERE
sh = gc.open_by_key(spreadsheet_key)
worksheet = sh.get_worksheet(sheet_index_no) #-> 0 - first sheet, 1 - second sheet etc. 

# APPEND DATA TO SHEET
set_with_dataframe(worksheet, user_df) #-> Upload user_df vào Sheet đầu tiên trong Spreadsheet

# DONE: Bây giờ bạn có thể mở spreadsheet và kiểm tra nội dung đã update chứ

# %% [markdown]
# ![slack_user_gsheet](https://github.com/vukhanhlinh/atom-assignments/blob/main/img/slack_user_gsheet.png?raw=1)

# %% [markdown]
# -------------- HẾT PHẦN OPTION 1 ---------------------

# %% [markdown]
# ## Option 2: Ai đã nộp bài?

# %% [markdown]
# ### Slack API: Channel List

# %%
## Gọi SLACK API để list tất cả các channel
endpoint = "https://slack.com/api/conversations.list"
headers = {"Authorization": "Bearer {}".format(os.environ['SLACK_BEARER_TOKEN'])}
response = requests.post(endpoint, headers=headers).json() 
channel_ls = response['channels']

# %%
channel_ls[0] ## Thử extract record đầu tiên để xem schema  => name: general, id: C01B4PVGLVB
# Out:
# {'created': 1600856703,
#  'creator': 'U01BE2PR6LU',
#  'id': 'C01B4PVGLVB',
#  'is_archived': False,
#  'is_channel': True,
#  'is_ext_shared': False,
#  'is_general': True,
#  'is_group': False,
#  'is_im': False,
#  'is_member': False,
#  'is_mpim': False,
#  'is_org_shared': False,
#  'is_pending_ext_shared': False,
#  'is_private': False,
#  'is_shared': False,
#  'name': 'general',
#  'name_normalized': 'general',
#  'num_members': 66,
#  'parent_conversation': None,
#  'pending_connected_team_ids': [],
#  'pending_shared': [],
#  'previous_names': [],
#  'purpose': {'creator': 'U01BE2PR6LU',
#   'last_set': 1600856703,
#   'value': 'This is the one channel that will always include everyone. It’s a great spot for announcements and team-wide conversations.'},
#  'shared_team_ids': ['T01B7SGGMLJ'],
#  'topic': {'creator': '', 'last_set': 0, 'value': ''},
#  'unlinked': 0}

# %% [markdown]
# ### TODO#3
# * Tìm id của channel #atom-assignment2

# %%
for i in channel_ls:
    print(i['name'])
# Out:
# general
# contents
# branding-design
# atom-assignment1
# atom-week1
# atom-general
# topics-data-analytics
# topics-python
# topics-materials
# atom-assignment2
# atom-week2
# atom-week3
# atom-assignment3
# atom-assignment4
# atom-week4
# atom-assignment5
# atom-week5
# atom-week6
# atom-assignment6

# %%
for i in channel_ls:
    if (i['name']) == 'atom-assignment2':
        print('atom-assignment2 id is: ', i['id'])
# Out:
# atom-assignment2 id is:  C021FSDN7LJ

# %% [markdown]
# # **Slack API: List messages trong 1 channel**

# %%
## Gọi SLACK API
endpoint = "https://slack.com/api/conversations.history"
data = {"channel": "C01U6P7LZ8F"} ## This is ID of assignment#1 channel
headers = {"Authorization": "Bearer {}".format(os.environ['SLACK_BEARER_TOKEN'])}

# %%
response_json = requests.post(endpoint, data=data, headers=headers).json()
msg_ls = response_json['messages']

# %%
msg_ls[21]
# Out:
# {'blocks': [{'block_id': 'aluFq',
#    'elements': [{'elements': [{'text': 'Cám ơn Quân nhiều nhé. Hay quá Quân ơi',
#        'type': 'text'}],
#      'type': 'rich_text_section'}],
#    'type': 'rich_text'}],
#  'client_msg_id': '21094a1f-9682-4838-96c7-17735444db09',
#  'reactions': [{'count': 1, 'name': 'heart', 'users': ['U01UMJ36QD9']}],
#  'root': {'attachments': [{'fallback': 'HackerRank: Between Two Sets | HackerRank',
#     'from_url': 'https://www.hackerrank.com/challenges/between-two-sets/problem',
#     'id': 1,
#     'original_url': 'https://www.hackerrank.com/challenges/between-two-sets/problem',
#     'service_icon': 'https://hrcdn.net/community-frontend/assets/favicon-ddc852f75a.png',
#     'service_name': 'HackerRank',
#     'text': 'Find the number of integers that satisfies certain criteria relative to two sets.',
#     'thumb_height': 640,
#     'thumb_url': 'https://hrcdn.net/og/default.jpg',
#     'thumb_width': 1200,
#     'title': 'Between Two Sets | HackerRank',
#     'title_link': 'https://www.hackerrank.com/challenges/between-two-sets/problem'},
#    {'fallback': 'Count and Say - LeetCode',
#     'from_url': 'https://leetcode.com/problems/count-and-say/',
#     'id': 2,
#     'image_bytes': 139567,
#     'image_height': 250,
#     'image_url': 'https://leetcode.com/static/images/LeetCode_Sharing.png',
#     'image_width': 481,
#     'original_url': 'https://leetcode.com/problems/count-and-say/',
#     'service_icon': 'https://leetcode.com/apple-touch-icon-57x57.png',
#     'service_name': 'LeetCode',
#     'text': 'Level up your coding skills and quickly land a job. This is the best place to expand your knowledge and get prepared for your next interview.',
#     'title': 'Count and Say - LeetCode',
#     'title_link': 'https://leetcode.com/problems/count-and-say/'}],
#   'blocks': [{'block_id': 'Ip1K',
#     'elements': [{'elements': [{'text': 'hi mọi người, ngoài ',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://www.hackerrank.com/challenges/between-two-sets/problem'},
#        {'text': ' mình xin phép được chia sẻ một nơi khác thực hành về Python: ',
#         'type': 'text'},
#        {'type': 'link', 'url': 'https://leetcode.com/problems/count-and-say/'},
#        {'text': '\nVới concept tương tự như bên Hackerrank . Bạn nào quan tâm thì có thể truy cập và làm thử trên này nhé.',
#         'type': 'text'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '7857690f-4e60-4495-bc93-349c785f5ebf',
#   'is_locked': False,
#   'latest_reply': '1620455803.006000',
#   'reply_count': 1,
#   'reply_users': ['U01UMBX2X18'],
#   'reply_users_count': 1,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'hi mọi người, ngoài <https://www.hackerrank.com/challenges/between-two-sets/problem> mình xin phép được chia sẻ một nơi khác thực hành về Python: <https://leetcode.com/problems/count-and-say/>\nVới concept tương tự như bên Hackerrank . Bạn nào quan tâm thì có thể truy cập và làm thử trên này nhé.',
#   'thread_ts': '1620455519.005200',
#   'ts': '1620455519.005200',
#   'type': 'message',
#   'user': 'U01UMJ36QD9'},
#  'subtype': 'thread_broadcast',
#  'text': 'Cám ơn Quân nhiều nhé. Hay quá Quân ơi',
#  'thread_ts': '1620455519.005200',
#  'ts': '1620455803.006000',
#  'type': 'message',
#  'user': 'U01UMBX2X18'}

# %%
not_learners_id = ['U01BE2PR6LU']

# %%
## Summarize all submitted assignments + reviews cnt
not_learners_id = ['U01BE2PR6LU'] # -> Remove MA from the user_id
github, reply_count, reply_users_count, reply_users, latest_reply = '','','','',''
for i in range(20):
  ts = dt.fromtimestamp(float(msg_ls[i]['ts'])) # -> Convert timestamp Epoch thành dàng dễ đọc
  user = msg_ls[i]['user'] # -> Lấy thông tin người post messages
  if msg_ls[i]['user'] not in not_learners_id:
    if 'attachments' in msg_ls[i].keys():
      #print(msg_ls[i].keys())
      text = msg_ls[i]['text']
      github_link = re.findall('(?:https?://)?(?:www[.])?github[.]com/[\w-]+/?', text) #-> Submission là các message có link github
      #print(msg_ls[i])
      if len(github_link) > 0: github = github_link[0]
      if 'reply_count' in msg_ls[i].keys(): reply_count = msg_ls[i]['reply_count'] #-> Extract số review
      if 'reply_users_count' in msg_ls[i].keys(): reply_users_count = msg_ls[i]['reply_users_count']
      if 'reply_users' in msg_ls[i].keys(): reply_users = msg_ls[i]['reply_users']
      if 'latest_reply' in msg_ls[i].keys(): latest_reply = dt.fromtimestamp(float(msg_ls[i]['latest_reply']))
      print(ts, user, reply_users_count, reply_users, latest_reply, github)
# Out:
# 2021-05-10 04:51:46.004700 U01UJ9LG5U5 2 ['U01USGKQ771', 'U01V00KHHHP'] 2021-05-15 09:14:31.003600 https://github.com/danhpcv/
# 2021-05-10 04:35:39.003800 U01UMC08KL2 2 ['U01UTGS5ZNY', 'U01UMC08KL2'] 2021-05-18 08:09:59.000800 https://github.com/auslynnguyen/

# %% [markdown]
# ### TODO#4
# * Tạo thành 1 bảng chứa các thông tin trên và update lên Spreadsheet (Sheet: Assignment#2 Submission)

# %%
## Gọi SLACK API
endpoint = "https://slack.com/api/conversations.history"
data = {"channel": "C01U6P7LZ8F"} ## This is ID of assignment#1 channel
headers = {"Authorization": "Bearer {}".format(os.environ['SLACK_BEARER_TOKEN'])}

# %%
##Lấy message
response_json = requests.post(endpoint, data=data, headers=headers).json()
msg_as2 = response_json['messages']

# %%
not_learners_id = ['U01BE2PR6LU'] #LoạiLoại MA ra khỏi user_id

# %%
msg_as2[34].keys()
# Out:
# dict_keys(['client_msg_id', 'type', 'text', 'user', 'ts', 'team', 'edited', 'attachments', 'blocks'])

# %%
msg_as2
# Out:
# [{'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1622694670.000600',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1622616102.000300',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1622216202.000300',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1621856793.004500',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1621756508.004100',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1621649053.002000',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1621573064.000900',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1621529006.000600',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1621475882.000300',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1621356309.001300',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1621271471.002600',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'subtype': 'channel_topic',
#   'text': '<@U01BE2PR6LU> set the channel topic: Assigment#1 - Python Basics &amp; Spreadsheet Analysis',
#   'topic': 'Assigment#1 - Python Basics &amp; Spreadsheet Analysis',
#   'ts': '1621074484.005600',
#   'type': 'message',
#   'user': 'U01BE2PR6LU'},
#  {'subtype': 'channel_topic',
#   'text': '<@U01BE2PR6LU> set the channel topic: Assigment#1 - Submissions + Reviews',
#   'topic': 'Assigment#1 - Submissions + Reviews',
#   'ts': '1621074460.005500',
#   'type': 'message',
#   'user': 'U01BE2PR6LU'},
#  {'purpose': 'Where learners submit assignments and give review for others',
#   'subtype': 'channel_purpose',
#   'text': '<@U01BE2PR6LU> set the channel description: Where learners submit assignments and give review for others',
#   'ts': '1621074440.005400',
#   'type': 'message',
#   'user': 'U01BE2PR6LU'},
#  {'subtype': 'channel_topic',
#   'text': '<@U01BE2PR6LU> set the channel topic: Assigment#1 Submissions + Reviews',
#   'topic': 'Assigment#1 Submissions + Reviews',
#   'ts': '1621074401.005300',
#   'type': 'message',
#   'user': 'U01BE2PR6LU'},
#  {'inviter': 'U01BE2PR6LU',
#   'subtype': 'channel_join',
#   'text': '<@U0226MQ73MJ> has joined the channel',
#   'ts': '1621072722.005000',
#   'type': 'message',
#   'user': 'U0226MQ73MJ'},
#  {'blocks': [{'block_id': 'TrZ',
#     'elements': [{'elements': [{'text': 'Em xin chào mọi người ạ. Híc, em bị stuck ở phần bài tập 2 nên ngoi lên nhờ mọi người chỉ giáo với ạ ',
#         'type': 'text'},
#        {'name': 'smiling_face_with_tear', 'type': 'emoji'},
#        {'text': ' \n\nCụ thể em làm tới đoạn App password và API xong, nhưng tới đoạn code từ !1s trong phần Environment Variables thì em không hiểu là mình viết đoạn này vào Google Colab hay vào đâu ạ? Em cũng thử trên Jupiter Notebook nhưng không được.\n\nFile bài đọc Medium ở #Lab2 em hiện chưa tìm cách nào vào được nên bị miss mất nội dung Set-up working environment ạ.\n\nKhông làm được bài nên ngứa ngáy trong mình ',
#         'type': 'text'},
#        {'name': 'joy', 'type': 'emoji'},
#        {'text': ', mong mọi người giúp đỡ ạ. Em xin cảm ơn ', 'type': 'text'},
#        {'name': 'pray', 'skin_tone': 2, 'type': 'emoji'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '005AD620-BD06-4123-BC42-6118DAA73BA4',
#   'is_locked': False,
#   'latest_reply': '1620928894.021400',
#   'reply_count': 5,
#   'reply_users': ['U01V00P4S2V', 'U01UTGRMGEQ', 'U01UMJ451V1', 'U01V00LQ7EV'],
#   'reply_users_count': 4,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Em xin chào mọi người ạ. Híc, em bị stuck ở phần bài tập 2 nên ngoi lên nhờ mọi người chỉ giáo với ạ :smiling_face_with_tear: \n\nCụ thể em làm tới đoạn App password và API xong, nhưng tới đoạn code từ !1s trong phần Environment Variables thì em không hiểu là mình viết đoạn này vào Google Colab hay vào đâu ạ? Em cũng thử trên Jupiter Notebook nhưng không được.\n\nFile bài đọc Medium ở #Lab2 em hiện chưa tìm cách nào vào được nên bị miss mất nội dung Set-up working environment ạ.\n\nKhông làm được bài nên ngứa ngáy trong mình :joy:, mong mọi người giúp đỡ ạ. Em xin cảm ơn :pray::skin-tone-2:',
#   'thread_ts': '1620914988.011000',
#   'ts': '1620914988.011000',
#   'type': 'message',
#   'user': 'U01UTGRMGEQ'},
#  {'attachments': [{'app_unfurl_url': 'https://github.com/danhpcv/datacracy-atom-danhpcv',
#     'bot_id': 'B01UQU8E2A3',
#     'color': '24292f',
#     'fallback': 'danhpcv/datacracy-atom-danhpcv',
#     'fields': [{'short': True,
#       'title': 'Language',
#       'value': 'Jupyter Notebook'},
#      {'short': True, 'title': 'Last updated', 'value': '17 days ago'}],
#     'id': 1,
#     'is_app_unfurl': True,
#     'title': 'danhpcv/datacracy-atom-danhpcv'},
#    {'fallback': 'Google Colaboratory',
#     'from_url': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1',
#     'id': 1,
#     'image_bytes': 4534,
#     'image_height': 250,
#     'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png',
#     'image_width': 250,
#     'original_url': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1',
#     'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210506-060122-RC00_372298824',
#     'service_name': 'colab.research.google.com',
#     'title': 'Google Colaboratory',
#     'title_link': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1'}],
#   'blocks': [{'block_id': 'iZh8',
#     'elements': [{'elements': [{'text': 'Hi all,\nMình gửi lại assignment phần 1 nhé\nTask 1: ',
#         'type': 'text'},
#        {'text': 'https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707',
#         'type': 'link',
#         'url': 'https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707'},
#        {'text': '\nTask 2: ', 'type': 'text'},
#        {'text': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1',
#         'type': 'link',
#         'url': 'https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1'},
#        {'text': '\nTask 3: ', 'type': 'text'},
#        {'text': 'https://github.com/danhpcv/datacracy-atom-danhpcv',
#         'type': 'link',
#         'url': 'https://github.com/danhpcv/datacracy-atom-danhpcv'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': 'D86A48D2-D953-4504-92BF-D9240B2549A8',
#   'is_locked': False,
#   'latest_reply': '1621070071.003600',
#   'reactions': [{'count': 1, 'name': '+1', 'users': ['U01UJ9P1S3X']},
#    {'count': 2,
#     'name': 'white_check_mark',
#     'users': ['U01USGKQ771', 'U01V00KHHHP']}],
#   'reply_count': 2,
#   'reply_users': ['U01USGKQ771', 'U01V00KHHHP'],
#   'reply_users_count': 2,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Hi all,\nMình gửi lại assignment phần 1 nhé\nTask 1: <https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707|https://docs.google.com/spreadsheets/d/1YUHbEJehnRlGHfsaqvgz3Mf0fYFMjCHgF4kz-WO2vQY/edit#gid=218077707>\nTask 2: <https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1|https://colab.research.google.com/drive/13mN-OGyMoIeEbkdFdwl-LqWohjG5sqiN#scrollTo=exHP3hO_khL1>\nTask 3: <https://github.com/danhpcv/datacracy-atom-danhpcv|https://github.com/danhpcv/datacracy-atom-danhpcv>',
#   'thread_ts': '1620622306.004700',
#   'ts': '1620622306.004700',
#   'type': 'message',
#   'user': 'U01UJ9LG5U5'},
#  {'attachments': [{'fallback': 'Google Colaboratory',
#     'from_url': 'https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing',
#     'id': 1,
#     'image_bytes': 4534,
#     'image_height': 250,
#     'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png',
#     'image_width': 250,
#     'original_url': 'https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing',
#     'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210506-060122-RC00_372298824',
#     'service_name': 'colab.research.google.com',
#     'title': 'Google Colaboratory',
#     'title_link': 'https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing'}],
#   'blocks': [{'block_id': '4teEx',
#     'elements': [{'elements': [{'text': 'Mình xin phép gửi bài Assignment 1 ạ. :D\nTask 1: ',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://docs.google.com/spreadsheets/d/1j_duRwbJeKKwVVetBEPo84HGbCVmAsFUj7YdreFszTk/edit?usp=sharing'},
#        {'text': '\nTask 2: ', 'type': 'text'},
#        {'type': 'link',
#         'url': 'https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing'},
#        {'text': '\nTask 3: ', 'type': 'text'},
#        {'type': 'link',
#         'url': 'https://github.com/auslynnguyen/datacracy-atom-thunguyen'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '246fb20c-8739-4664-9bcf-14f57aee17f7',
#   'is_locked': False,
#   'latest_reply': '1621325399.000800',
#   'reply_count': 2,
#   'reply_users': ['U01UTGS5ZNY', 'U01UMC08KL2'],
#   'reply_users_count': 2,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Mình xin phép gửi bài Assignment 1 ạ. :D\nTask 1: <https://docs.google.com/spreadsheets/d/1j_duRwbJeKKwVVetBEPo84HGbCVmAsFUj7YdreFszTk/edit?usp=sharing>\nTask 2: <https://colab.research.google.com/drive/1HN0jrXCqO7NDeuzeIXkOxbrZF47qgN5H?usp=sharing>\nTask 3: <https://github.com/auslynnguyen/datacracy-atom-thunguyen>',
#   'thread_ts': '1620621339.003800',
#   'ts': '1620621339.003800',
#   'type': 'message',
#   'user': 'U01UMC08KL2'},
#  {'blocks': [{'block_id': 'ztP7v',
#     'elements': [{'elements': [{'text': 'Em xin phép nộp lại bài ạ. Hôm bữa em hơi lag nên nộp nhầm channel =]]\n',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://docs.google.com/document/d/1t-NkkOyub7ltbGvEHZmw3SPtgW3BrH8aWIase87VrWg/edit?usp=sharing'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '4214088f-ccdc-4e8e-9c19-677ae3f439a1',
#   'is_locked': False,
#   'latest_reply': '1621070896.004000',
#   'reactions': [{'count': 1,
#     'name': 'white_check_mark',
#     'users': ['U01V00KHHHP']}],
#   'reply_count': 3,
#   'reply_users': ['U01VB632FPS', 'U01V00KHHHP'],
#   'reply_users_count': 2,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Em xin phép nộp lại bài ạ. Hôm bữa em hơi lag nên nộp nhầm channel =]]\n<https://docs.google.com/document/d/1t-NkkOyub7ltbGvEHZmw3SPtgW3BrH8aWIase87VrWg/edit?usp=sharing>',
#   'thread_ts': '1620616055.001200',
#   'ts': '1620616055.001200',
#   'type': 'message',
#   'user': 'U01UTGRQS9J'},
#  {'attachments': [{'author_icon': 'https://secure.gravatar.com/avatar/dcf7e1aca86cc2adb657e2bd2415352f.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-48.png',
#     'author_id': 'U01BE2PR6LU',
#     'author_link': 'https://datacracy.slack.com/team/U01BE2PR6LU',
#     'author_name': 'Đặng Huỳnh Mai Anh',
#     'author_subname': 'Đặng Huỳnh Mai Anh',
#     'channel_id': 'C01B4PVGLVB',
#     'channel_name': 'general',
#     'fallback': '[May 7th, 2021 11:41 PM] maianhdang.ftu: *Week 2-3 TODO List*\n*-----*\n*<!channel>* \nNhư vậy chúng ta đã xong buổi học thứ hai. Cảm ơn mọi người đã tham gia một buổi học rất vui, với tinh thần học hỏi cao, và rất thẳng thắn góp ý cho dự án\n&gt; *Assignment 1*\n• :calendar: `Tối nay. Thứ bảy, May 8, 2021`: các mentors sẽ gửi *General Feedback* trên <#C01U6P7LZ8F|atom-assignment1> để các bạn chỉnh sửa lại bài Assignment 1\n• :calendar: Để các bạn có thêm thời gian sửa bài theo Feedback, Deadline Submit lại bài <#C01U6P7LZ8F|atom-assignment1> dời lại từ Trưa CN May 9 =&gt; `Trưa 12:00pm, Thứ hai May 10`\n• Sau hạn trên, các bạn chủ động lên <#C01U6P7LZ8F|atom-assignment1> Peer-reviewed bài tập cho 2 bạn learner khác *(Hoàn thành trước buổi học tiếp theo Week 3 - Thứ 7 tuần sau)*\n    ◦ Bài nào bạn đang xem: react :construction: (các bạn skip các bài đã có bạn xem rồi)\n    ◦ Bài nào đã review song: react :white_check_mark: \n    ◦ Nội dung review:\n        ▪︎ (+) Bạn thấy bài làm có điểm gì hay?\n        ▪︎ (-) Bạn thấy bài có điểm gì cần improve?\n        ▪︎ `Chỉ mang tính tham khảo:` So với các tiêu chí được nêu trong General Feedback, bạn nghĩ bài làm đạt bao nhiêu % (trên 100% yêu cầu)\n&gt; *Assignment 2*\n• Vì nhận thấy bài tập Assignment 1 hơi nặng so với mọi người, Assignment 2 sẽ nhẹ nhàng và vui vẻ hơn. Sẽ share trên Slack vào `Trưa 12:00pm, Thứ hai May 10`\n• *Deadline:* ~Trước buổi học tiếp theo~, `19:00, Thứ 5 hàng tuần (để các mentors có thời gian review sơ)`\n&gt; *Discussion Channel*\nChúng ta sẽ học nhiều hơn và gần gũi hơn bằng việc chia sẻ thêm và thêm nữa. Mình có 3 channels theo topics để các bạn "tâm sự" với nhau và với mentors:\n• <#C0213MNH9L6|topics-python>: Hỏi đáp chia sẻ về Python - Mentors of Topics (<@U01VBGPP1EU> <@U01UJKRQM2R>)\n• <#C0213MNH9L6|topics-python>: Hỏi đáp chia sẻ về Data và Analytics - Mentors of Topics (<@U020P6WPAQJ> <@U01UMJ4J38B> <@U01UMJ4D5NX> <@U01UMBX2X18>)\n• <#C0213N56M2A|topics-materials>: Chia sẻ chung về các materials + khoá học thú vị. Cũng như nếu bạn có feedback muốn thay đổi gì trong Syllabus + Contents của ATOM (Syllabus Atom hoàn toàn mở và linh động để thay đổi cho phù hợp nhé) - Mentors of topics (<@U01V00LQ7EV> <@U01BE2PR6LU>)',
#     'footer': 'Posted in #general',
#     'from_url': 'https://datacracy.slack.com/archives/C01B4PVGLVB/p1620456097019400',
#     'id': 1,
#     'is_msg_unfurl': True,
#     'mrkdwn_in': ['text'],
#     'original_url': 'https://datacracy.slack.com/archives/C01B4PVGLVB/p1620456097019400',
#     'text': '*Week 2-3 TODO List*\n*-----*\n*<!channel>* \nNhư vậy chúng ta đã xong buổi học thứ hai. Cảm ơn mọi người đã tham gia một buổi học rất vui, với tinh thần học hỏi cao, và rất thẳng thắn góp ý cho dự án\n&gt; *Assignment 1*\n• :calendar: `Tối nay. Thứ bảy, May 8, 2021`: các mentors sẽ gửi *General Feedback* trên <#C01U6P7LZ8F|atom-assignment1> để các bạn chỉnh sửa lại bài Assignment 1\n• :calendar: Để các bạn có thêm thời gian sửa bài theo Feedback, Deadline Submit lại bài <#C01U6P7LZ8F|atom-assignment1> dời lại từ Trưa CN May 9 =&gt; `Trưa 12:00pm, Thứ hai May 10`\n• Sau hạn trên, các bạn chủ động lên <#C01U6P7LZ8F|atom-assignment1> Peer-reviewed bài tập cho 2 bạn learner khác *(Hoàn thành trước buổi học tiếp theo Week 3 - Thứ 7 tuần sau)*\n    ◦ Bài nào bạn đang xem: react :construction: (các bạn skip các bài đã có bạn xem rồi)\n    ◦ Bài nào đã review song: react :white_check_mark: \n    ◦ Nội dung review:\n        ▪︎ (+) Bạn thấy bài làm có điểm gì hay?\n        ▪︎ (-) Bạn thấy bài có điểm gì cần improve?\n        ▪︎ `Chỉ mang tính tham khảo:` So với các tiêu chí được nêu trong General Feedback, bạn nghĩ bài làm đạt bao nhiêu % (trên 100% yêu cầu)\n&gt; *Assignment 2*\n• Vì nhận thấy bài tập Assignment 1 hơi nặng so với mọi người, Assignment 2 sẽ nhẹ nhàng và vui vẻ hơn. Sẽ share trên Slack vào `Trưa 12:00pm, Thứ hai May 10`\n• *Deadline:* ~Trước buổi học tiếp theo~, `19:00, Thứ 5 hàng tuần (để các mentors có thời gian review sơ)`\n&gt; *Discussion Channel*\nChúng ta sẽ học nhiều hơn và gần gũi hơn bằng việc chia sẻ thêm và thêm nữa. Mình có 3 channels theo topics để các bạn "tâm sự" với nhau và với mentors:\n• <#C0213MNH9L6|topics-python>: Hỏi đáp chia sẻ về Python - Mentors of Topics (<@U01VBGPP1EU> <@U01UJKRQM2R>)\n• <#C0213MNH9L6|topics-python>: Hỏi đáp chia sẻ về Data và Analytics - Mentors of Topics (<@U020P6WPAQJ> <@U01UMJ4J38B> <@U01UMJ4D5NX> <@U01UMBX2X18>)\n• <#C0213N56M2A|topics-materials>: Chia sẻ chung về các materials + khoá học thú vị. Cũng như nếu bạn có feedback muốn thay đổi gì trong Syllabus + Contents của ATOM (Syllabus Atom hoàn toàn mở và linh động để thay đổi cho phù hợp nhé) - Mentors of topics (<@U01V00LQ7EV> <@U01BE2PR6LU>)',
#     'ts': '1620456097.019400'}],
#   'blocks': [{'block_id': 'GwT',
#     'elements': [{'elements': [{'type': 'link',
#         'url': 'https://datacracy.slack.com/archives/C01B4PVGLVB/p1620456097019400'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': 'cfad12f7-bf9c-4209-b563-f495f378fb1f',
#   'pinned_info': {'channel': 'C01U6P7LZ8F',
#    'pinned_by': 'U01BE2PR6LU',
#    'pinned_ts': 1620456214},
#   'pinned_to': ['C01U6P7LZ8F'],
#   'reactions': [{'count': 3,
#     'name': 'heart',
#     'users': ['U01V00KHHHP', 'U01UMBZHU2W', 'U01UMC0N5U2']},
#    {'count': 1, 'name': 'clap', 'users': ['U01UMBZHU2W']}],
#   'team': 'T01B7SGGMLJ',
#   'text': '<https://datacracy.slack.com/archives/C01B4PVGLVB/p1620456097019400>',
#   'ts': '1620456205.006900',
#   'type': 'message',
#   'user': 'U01BE2PR6LU'},
#  {'blocks': [{'block_id': 'aluFq',
#     'elements': [{'elements': [{'text': 'Cám ơn Quân nhiều nhé. Hay quá Quân ơi',
#         'type': 'text'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '21094a1f-9682-4838-96c7-17735444db09',
#   'reactions': [{'count': 1, 'name': 'heart', 'users': ['U01UMJ36QD9']}],
#   'root': {'attachments': [{'fallback': 'HackerRank: Between Two Sets | HackerRank',
#      'from_url': 'https://www.hackerrank.com/challenges/between-two-sets/problem',
#      'id': 1,
#      'original_url': 'https://www.hackerrank.com/challenges/between-two-sets/problem',
#      'service_icon': 'https://hrcdn.net/community-frontend/assets/favicon-ddc852f75a.png',
#      'service_name': 'HackerRank',
#      'text': 'Find the number of integers that satisfies certain criteria relative to two sets.',
#      'thumb_height': 640,
#      'thumb_url': 'https://hrcdn.net/og/default.jpg',
#      'thumb_width': 1200,
#      'title': 'Between Two Sets | HackerRank',
#      'title_link': 'https://www.hackerrank.com/challenges/between-two-sets/problem'},
#     {'fallback': 'Count and Say - LeetCode',
#      'from_url': 'https://leetcode.com/problems/count-and-say/',
#      'id': 2,
#      'image_bytes': 139567,
#      'image_height': 250,
#      'image_url': 'https://leetcode.com/static/images/LeetCode_Sharing.png',
#      'image_width': 481,
#      'original_url': 'https://leetcode.com/problems/count-and-say/',
#      'service_icon': 'https://leetcode.com/apple-touch-icon-57x57.png',
#      'service_name': 'LeetCode',
#      'text': 'Level up your coding skills and quickly land a job. This is the best place to expand your knowledge and get prepared for your next interview.',
#      'title': 'Count and Say - LeetCode',
#      'title_link': 'https://leetcode.com/problems/count-and-say/'}],
#    'blocks': [{'block_id': 'Ip1K',
#      'elements': [{'elements': [{'text': 'hi mọi người, ngoài ',
#          'type': 'text'},
#         {'type': 'link',
#          'url': 'https://www.hackerrank.com/challenges/between-two-sets/problem'},
#         {'text': ' mình xin phép được chia sẻ một nơi khác thực hành về Python: ',
#          'type': 'text'},
#         {'type': 'link',
#          'url': 'https://leetcode.com/problems/count-and-say/'},
#         {'text': '\nVới concept tương tự như bên Hackerrank . Bạn nào quan tâm thì có thể truy cập và làm thử trên này nhé.',
#          'type': 'text'}],
#        'type': 'rich_text_section'}],
#      'type': 'rich_text'}],
#    'client_msg_id': '7857690f-4e60-4495-bc93-349c785f5ebf',
#    'is_locked': False,
#    'latest_reply': '1620455803.006000',
#    'reply_count': 1,
#    'reply_users': ['U01UMBX2X18'],
#    'reply_users_count': 1,
#    'subscribed': False,
#    'team': 'T01B7SGGMLJ',
#    'text': 'hi mọi người, ngoài <https://www.hackerrank.com/challenges/between-two-sets/problem> mình xin phép được chia sẻ một nơi khác thực hành về Python: <https://leetcode.com/problems/count-and-say/>\nVới concept tương tự như bên Hackerrank . Bạn nào quan tâm thì có thể truy cập và làm thử trên này nhé.',
#    'thread_ts': '1620455519.005200',
#    'ts': '1620455519.005200',
#    'type': 'message',
#    'user': 'U01UMJ36QD9'},
#   'subtype': 'thread_broadcast',
#   'text': 'Cám ơn Quân nhiều nhé. Hay quá Quân ơi',
#   'thread_ts': '1620455519.005200',
#   'ts': '1620455803.006000',
#   'type': 'message',
#   'user': 'U01UMBX2X18'},
#  {'attachments': [{'fallback': 'HackerRank: Between Two Sets | HackerRank',
#     'from_url': 'https://www.hackerrank.com/challenges/between-two-sets/problem',
#     'id': 1,
#     'original_url': 'https://www.hackerrank.com/challenges/between-two-sets/problem',
#     'service_icon': 'https://hrcdn.net/community-frontend/assets/favicon-ddc852f75a.png',
#     'service_name': 'HackerRank',
#     'text': 'Find the number of integers that satisfies certain criteria relative to two sets.',
#     'thumb_height': 640,
#     'thumb_url': 'https://hrcdn.net/og/default.jpg',
#     'thumb_width': 1200,
#     'title': 'Between Two Sets | HackerRank',
#     'title_link': 'https://www.hackerrank.com/challenges/between-two-sets/problem'},
#    {'fallback': 'Count and Say - LeetCode',
#     'from_url': 'https://leetcode.com/problems/count-and-say/',
#     'id': 2,
#     'image_bytes': 139567,
#     'image_height': 250,
#     'image_url': 'https://leetcode.com/static/images/LeetCode_Sharing.png',
#     'image_width': 481,
#     'original_url': 'https://leetcode.com/problems/count-and-say/',
#     'service_icon': 'https://leetcode.com/apple-touch-icon-57x57.png',
#     'service_name': 'LeetCode',
#     'text': 'Level up your coding skills and quickly land a job. This is the best place to expand your knowledge and get prepared for your next interview.',
#     'title': 'Count and Say - LeetCode',
#     'title_link': 'https://leetcode.com/problems/count-and-say/'}],
#   'blocks': [{'block_id': 'Ip1K',
#     'elements': [{'elements': [{'text': 'hi mọi người, ngoài ',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://www.hackerrank.com/challenges/between-two-sets/problem'},
#        {'text': ' mình xin phép được chia sẻ một nơi khác thực hành về Python: ',
#         'type': 'text'},
#        {'type': 'link', 'url': 'https://leetcode.com/problems/count-and-say/'},
#        {'text': '\nVới concept tương tự như bên Hackerrank . Bạn nào quan tâm thì có thể truy cập và làm thử trên này nhé.',
#         'type': 'text'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '7857690f-4e60-4495-bc93-349c785f5ebf',
#   'is_locked': False,
#   'latest_reply': '1620455803.006000',
#   'reactions': [{'count': 2,
#     'name': 'raised_hands',
#     'users': ['U01V082PLN5', 'U01UMBX2X18']},
#    {'count': 5,
#     'name': 'heart',
#     'users': ['U01U6JQB695',
#      'U01V082PLN5',
#      'U01UJ9PRT5K',
#      'U01UMC0N5U2',
#      'U01UTGRP0HJ']},
#    {'count': 2,
#     'name': 'white_check_mark',
#     'users': ['U01BE2PR6LU', 'U01VB632FPS']},
#    {'count': 3,
#     'name': '+1',
#     'users': ['U01UMJ451V1', 'U01UJ9P1S3X', 'U01UTGRP0HJ']}],
#   'reply_count': 1,
#   'reply_users': ['U01UMBX2X18'],
#   'reply_users_count': 1,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'hi mọi người, ngoài <https://www.hackerrank.com/challenges/between-two-sets/problem> mình xin phép được chia sẻ một nơi khác thực hành về Python: <https://leetcode.com/problems/count-and-say/>\nVới concept tương tự như bên Hackerrank . Bạn nào quan tâm thì có thể truy cập và làm thử trên này nhé.',
#   'thread_ts': '1620455519.005200',
#   'ts': '1620455519.005200',
#   'type': 'message',
#   'user': 'U01UMJ36QD9'},
#  {'blocks': [{'block_id': '=qDs',
#     'elements': [{'elements': [{'text': 'Hi anh chị, em xin phép gửi lại link Task 1, anh chị Mentor check giúp em xem được chưa ạ ',
#         'type': 'text'},
#        {'type': 'user', 'user_id': 'U01UMBX2X18'},
#        {'text': ' ', 'type': 'text'},
#        {'type': 'user', 'user_id': 'U01BE2PR6LU'},
#        {'text': '\n', 'type': 'text'},
#        {'type': 'link',
#         'url': 'https://docs.google.com/spreadsheets/d/1ArM8cxJNU4H17t9Ts3TnJkcvRLorTOmewW96oucYlCI/edit?usp=sharing'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '341f3fd5-41d4-4d37-bc49-be1f84547c97',
#   'display_as_bot': False,
#   'files': [{'created': 1619170479,
#     'display_as_bot': False,
#     'editable': False,
#     'external_id': '1ArM8cxJNU4H17t9Ts3TnJkcvRLorTOmewW96oucYlCI',
#     'external_type': 'gdrive',
#     'external_url': 'https://docs.google.com/spreadsheets/d/1ArM8cxJNU4H17t9Ts3TnJkcvRLorTOmewW96oucYlCI/edit#gid=4530119',
#     'filetype': 'gsheet',
#     'has_rich_preview': True,
#     'id': 'F0200J6G5FW',
#     'is_external': True,
#     'is_public': True,
#     'is_starred': False,
#     'mimetype': 'application/vnd.google-apps.spreadsheet',
#     'mode': 'external',
#     'name': 'TASK 1_CVH_Analytics on Google Spreadsheet',
#     'original_h': 1449,
#     'original_w': 1024,
#     'permalink': 'https://datacracy.slack.com/files/U01UMC0N5U2/F0200J6G5FW/task_1_cvh_analytics_on_google_spreadsheet',
#     'pretty_type': 'G Suite Spreadsheet',
#     'public_url_shared': False,
#     'size': 339666,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0200J6G5FW-3be99437e4/task_1_cvh_analytics_on_google_spreadsheet_1024.png',
#     'thumb_1024_h': 1024,
#     'thumb_1024_w': 724,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0200J6G5FW-3be99437e4/task_1_cvh_analytics_on_google_spreadsheet_160.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0200J6G5FW-3be99437e4/task_1_cvh_analytics_on_google_spreadsheet_360.png',
#     'thumb_360_h': 360,
#     'thumb_360_w': 254,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0200J6G5FW-3be99437e4/task_1_cvh_analytics_on_google_spreadsheet_480.png',
#     'thumb_480_h': 480,
#     'thumb_480_w': 339,
#     'thumb_64': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0200J6G5FW-3be99437e4/task_1_cvh_analytics_on_google_spreadsheet_64.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0200J6G5FW-3be99437e4/task_1_cvh_analytics_on_google_spreadsheet_720.png',
#     'thumb_720_h': 720,
#     'thumb_720_w': 509,
#     'thumb_80': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0200J6G5FW-3be99437e4/task_1_cvh_analytics_on_google_spreadsheet_80.png',
#     'thumb_800': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0200J6G5FW-3be99437e4/task_1_cvh_analytics_on_google_spreadsheet_800.png',
#     'thumb_800_h': 1132,
#     'thumb_800_w': 800,
#     'thumb_960': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0200J6G5FW-3be99437e4/task_1_cvh_analytics_on_google_spreadsheet_960.png',
#     'thumb_960_h': 960,
#     'thumb_960_w': 678,
#     'thumb_tiny': 'AwAwACHRZippNx254ok60n8FADgT7UAnIoFA6igB1FFFADJOtJ/BSydaT+CgBwoHUUCgdRQA6iiigAooooAKKKKACiiigD//2Q==',
#     'timestamp': 1619170479,
#     'title': 'TASK 1_Chu Việt Hồng_Analytics on Google Spreadsheet',
#     'url_private': 'https://docs.google.com/spreadsheets/d/1ArM8cxJNU4H17t9Ts3TnJkcvRLorTOmewW96oucYlCI/edit#gid=4530119',
#     'user': 'U01UMC0N5U2',
#     'username': ''}],
#   'reactions': [{'count': 1, 'name': 'eyes', 'users': ['U01BE2PR6LU']},
#    {'count': 1, 'name': 'raised_hands', 'users': ['U01BE2PR6LU']}],
#   'text': 'Hi anh chị, em xin phép gửi lại link Task 1, anh chị Mentor check giúp em xem được chưa ạ <@U01UMBX2X18> <@U01BE2PR6LU>\n<https://docs.google.com/spreadsheets/d/1ArM8cxJNU4H17t9Ts3TnJkcvRLorTOmewW96oucYlCI/edit?usp=sharing>',
#   'ts': '1620442573.001700',
#   'type': 'message',
#   'upload': False,
#   'user': 'U01UMC0N5U2',
#   'x_files': ['F0200J6G5FW']},
#  {'blocks': [{'block_id': 'Cw0U8',
#     'elements': [{'elements': [{'text': 'Chắc em chốt sổ gửi assignment 1 ạ :))\nBài 1: ',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://drive.google.com/file/d/1ng9wV6LFTv5lDyJSBv2nYaOlfTKvL9s0/view?usp=sharing'},
#        {'text': '\nBài 2: ', 'type': 'text'},
#        {'type': 'link',
#         'url': 'https://colab.research.google.com/drive/1rY0pc1FFzSRpjbWv7DTE8WmhqlD6pKzO?usp=sharing'},
#        {'text': '\nBài 3: ', 'type': 'text'},
#        {'type': 'link',
#         'url': 'https://github.com/TrangNgo1709/datacracy-atom-Ngo-Thi-Minh-Trang'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '4abf215d-ff30-44c0-9384-9da735a374c1',
#   'edited': {'ts': '1620405397.000000', 'user': 'U01USGKQ771'},
#   'is_locked': False,
#   'latest_reply': '1620701520.000200',
#   'reactions': [{'count': 1, 'name': '+1', 'users': ['U01VB632FPS']},
#    {'count': 1, 'name': 'white_check_mark', 'users': ['U01UMC0N5U2']}],
#   'reply_count': 1,
#   'reply_users': ['U01UMC0N5U2'],
#   'reply_users_count': 1,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Chắc em chốt sổ gửi assignment 1 ạ :))\nBài 1: <https://drive.google.com/file/d/1ng9wV6LFTv5lDyJSBv2nYaOlfTKvL9s0/view?usp=sharing>\nBài 2: <https://colab.research.google.com/drive/1rY0pc1FFzSRpjbWv7DTE8WmhqlD6pKzO?usp=sharing>\nBài 3: <https://github.com/TrangNgo1709/datacracy-atom-Ngo-Thi-Minh-Trang>',
#   'thread_ts': '1620404988.000700',
#   'ts': '1620404988.000700',
#   'type': 'message',
#   'user': 'U01USGKQ771'},
#  {'attachments': [{'app_unfurl_url': 'https://github.com/hoaintp/datacracy-atom-hoaintp',
#     'bot_id': 'B01UQU8E2A3',
#     'color': '24292f',
#     'fallback': 'hoaintp/datacracy-atom-hoaintp',
#     'fields': [{'short': True,
#       'title': 'Language',
#       'value': 'Jupyter Notebook'},
#      {'short': True, 'title': 'Last updated', 'value': '23 minutes ago'}],
#     'id': 1,
#     'is_app_unfurl': True,
#     'title': 'hoaintp/datacracy-atom-hoaintp'}],
#   'blocks': [{'block_id': 'Ldw',
#     'elements': [{'elements': [{'text': 'Chào mọi người, em gửi assignment 1 ạ: \n',
#         'type': 'text'},
#        {'text': 'https://github.com/hoaintp/datacracy-atom-hoaintp',
#         'type': 'link',
#         'url': 'https://github.com/hoaintp/datacracy-atom-hoaintp'},
#        {'text': '\nHẹn gặp mọi người thứ 7 này ', 'type': 'text'},
#        {'name': 'two_hearts', 'type': 'emoji'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': 'CB7D6549-3D83-408E-A485-8DCA4C95DC4C',
#   'reactions': [{'count': 1,
#     'name': 'construction',
#     'users': ['U01UJ9LG5U5']}],
#   'team': 'T01B7SGGMLJ',
#   'text': 'Chào mọi người, em gửi assignment 1 ạ: \n<https://github.com/hoaintp/datacracy-atom-hoaintp|https://github.com/hoaintp/datacracy-atom-hoaintp>\nHẹn gặp mọi người thứ 7 này :two_hearts:',
#   'ts': '1620136546.001800',
#   'type': 'message',
#   'user': 'U01UTGVPE7N'},
#  {'attachments': [{'fallback': 'Google Colaboratory',
#     'from_url': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing',
#     'id': 1,
#     'image_bytes': 4534,
#     'image_height': 250,
#     'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png',
#     'image_width': 250,
#     'original_url': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing',
#     'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210429-060047-RC00_371090719',
#     'service_name': 'colab.research.google.com',
#     'title': 'Google Colaboratory',
#     'title_link': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing'}],
#   'blocks': [{'block_id': '7wmK',
#     'elements': [{'elements': [{'text': 'Em gửi Assignment 1 ạ:\n',
#         'type': 'text'}],
#       'type': 'rich_text_section'},
#      {'elements': [{'elements': [{'text': 'Task 1: ', 'type': 'text'},
#          {'text': 'https://docs.google.com/spreadsheets/d/1bjuqHqDIfUZHL7l562HOQ8je7jwzG3cDzp5M-MVpZms/edit?usp=sharing',
#           'type': 'link',
#           'url': 'https://docs.google.com/spreadsheets/d/1bjuqHqDIfUZHL7l562HOQ8je7jwzG3cDzp5M-MVpZms/edit?usp=sharing'}],
#         'type': 'rich_text_section'},
#        {'elements': [{'text': 'Task 2:\xa0', 'type': 'text'},
#          {'text': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing',
#           'type': 'link',
#           'url': 'https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing'},
#          {'text': '\n', 'type': 'text'}],
#         'type': 'rich_text_section'},
#        {'elements': [{'text': 'Task 3:\xa0', 'type': 'text'},
#          {'text': 'https://github.com/Tenderriver/datacracy-atom--Phan-Thuy-Giang-',
#           'type': 'link',
#           'url': 'https://github.com/Tenderriver/datacracy-atom--Phan-Thuy-Giang-'}],
#         'type': 'rich_text_section'}],
#       'indent': 0,
#       'offset': 0,
#       'style': 'ordered',
#       'type': 'rich_text_list'}],
#     'type': 'rich_text'}],
#   'client_msg_id': 'ab6d23e2-f50e-465e-881b-1327d5ce437c',
#   'edited': {'ts': '1620065267.000000', 'user': 'U01U6JQB695'},
#   'is_locked': False,
#   'latest_reply': '1620702606.001300',
#   'reactions': [{'count': 1,
#     'name': 'white_check_mark',
#     'users': ['U01UMC0N5U2']}],
#   'reply_count': 2,
#   'reply_users': ['U01UMC0N5U2', 'U01U6JQB695'],
#   'reply_users_count': 2,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Em gửi Assignment 1 ạ:\n1. Task 1: <https://docs.google.com/spreadsheets/d/1bjuqHqDIfUZHL7l562HOQ8je7jwzG3cDzp5M-MVpZms/edit?usp=sharing|https://docs.google.com/spreadsheets/d/1bjuqHqDIfUZHL7l562HOQ8je7jwzG3cDzp5M-MVpZms/edit?usp=sharing>\n2. Task 2:\xa0<https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing|https://colab.research.google.com/drive/1zWbE-TC1Yw5TBUen4ezrP51sV68ezhfD?usp=sharing>\n\n3. Task 3:\xa0<https://github.com/Tenderriver/datacracy-atom--Phan-Thuy-Giang-|https://github.com/Tenderriver/datacracy-atom--Phan-Thuy-Giang->',
#   'thread_ts': '1620063678.002400',
#   'ts': '1620063678.002400',
#   'type': 'message',
#   'user': 'U01U6JQB695'},
#  {'attachments': [{'app_unfurl_url': 'https://github.com/saturn1101/datacracy-atom-phuong-tran',
#     'bot_id': 'B01UQU8E2A3',
#     'color': '24292f',
#     'fallback': 'saturn1101/datacracy-atom-phuong-tran',
#     'fields': [{'short': True,
#       'title': 'Language',
#       'value': 'Jupyter Notebook'},
#      {'short': True, 'title': 'Last updated', 'value': '6 minutes ago'}],
#     'id': 1,
#     'is_app_unfurl': True,
#     'title': 'saturn1101/datacracy-atom-phuong-tran'},
#    {'fallback': 'Google Colaboratory',
#     'from_url': 'https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing',
#     'id': 1,
#     'image_bytes': 4534,
#     'image_height': 250,
#     'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png',
#     'image_width': 250,
#     'original_url': 'https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing',
#     'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210429-060047-RC00_371090719',
#     'service_name': 'colab.research.google.com',
#     'title': 'Google Colaboratory',
#     'title_link': 'https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing'}],
#   'blocks': [{'block_id': 'rsRb',
#     'elements': [{'elements': [{'text': 'Em gửi Assignment 1 ạ:\n',
#         'type': 'text'}],
#       'type': 'rich_text_section'},
#      {'elements': [{'elements': [{'text': 'Link ', 'type': 'text'},
#          {'style': {'bold': True},
#           'text': 'Google Spreadsheet',
#           'type': 'text'},
#          {'text': ' Task 1: ', 'type': 'text'},
#          {'type': 'link',
#           'url': 'https://docs.google.com/spreadsheets/d/1HaV9sUI6UQzgcRqpzkGy18XYlzcon2hWiFGuKhnz5IU/edit?usp=sharing'}],
#         'type': 'rich_text_section'},
#        {'elements': [{'text': 'Link ', 'type': 'text'},
#          {'style': {'bold': True}, 'text': 'Google Colab', 'type': 'text'},
#          {'text': ' Task 2: ', 'type': 'text'},
#          {'type': 'link',
#           'url': 'https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing'}],
#         'type': 'rich_text_section'},
#        {'elements': [{'text': 'Github: ', 'type': 'text'},
#          {'type': 'link',
#           'url': 'https://github.com/saturn1101/datacracy-atom-phuong-tran'}],
#         'type': 'rich_text_section'}],
#       'indent': 0,
#       'style': 'ordered',
#       'type': 'rich_text_list'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '8a6f0a0c-f0dc-4666-b667-0f659766908f',
#   'is_locked': False,
#   'latest_reply': '1621014686.024600',
#   'reactions': [{'count': 1, 'name': '+1', 'users': ['U01VB632FPS']},
#    {'count': 1, 'name': 'white_check_mark', 'users': ['U01UMBZHU2W']}],
#   'reply_count': 1,
#   'reply_users': ['U01UMBZHU2W'],
#   'reply_users_count': 1,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Em gửi Assignment 1 ạ:\n1. Link *Google Spreadsheet* Task 1: <https://docs.google.com/spreadsheets/d/1HaV9sUI6UQzgcRqpzkGy18XYlzcon2hWiFGuKhnz5IU/edit?usp=sharing>\n2. Link *Google Colab* Task 2: <https://colab.research.google.com/drive/1ilny8bAtOMOT57mVxJDoEZyQWJ_9-UvX?usp=sharing>\n3. Github: <https://github.com/saturn1101/datacracy-atom-phuong-tran>',
#   'thread_ts': '1620031879.001200',
#   'ts': '1620031879.001200',
#   'type': 'message',
#   'user': 'U01V00KHHHP'},
#  {'attachments': [{'fallback': "Vy's Notion on Notion: Lê Thảo Vy - Assignment 1",
#     'from_url': 'https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2',
#     'id': 1,
#     'original_url': 'https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2',
#     'service_name': "Vy's Notion on Notion",
#     'text': 'Task 1: link',
#     'title': 'Lê Thảo Vy - Assignment 1',
#     'title_link': 'https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2'}],
#   'blocks': [{'block_id': 'E8w3f',
#     'elements': [{'elements': [{'text': 'Chào mọi người, mình gửi assignment 1 nhaa:\n',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2'},
#        {'text': '\nChúc mọi người một đầu tuần vui vẻ ^^', 'type': 'text'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': 'a206160a-3b59-44d0-a800-091897d7fcc7',
#   'is_locked': False,
#   'latest_reply': '1621014755.025100',
#   'reactions': [{'count': 1,
#     'name': 'white_check_mark',
#     'users': ['U01UMJ451V1']}],
#   'reply_count': 2,
#   'reply_users': ['U01UMJ451V1', 'U01UMBZHU2W'],
#   'reply_users_count': 2,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Chào mọi người, mình gửi assignment 1 nhaa:\n<https://www.notion.so/L-Th-o-Vy-Assignment-1-f2df526a7fb74d8a9d305061f6772cc2>\nChúc mọi người một đầu tuần vui vẻ ^^',
#   'thread_ts': '1619420036.000800',
#   'ts': '1619420036.000800',
#   'type': 'message',
#   'user': 'U01UMBZHU2W'},
#  {'attachments': [{'app_unfurl_url': 'https://github.com/AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu',
#     'bot_id': 'B01UQU8E2A3',
#     'color': '24292f',
#     'fallback': 'AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu',
#     'fields': [{'short': True,
#       'title': 'Language',
#       'value': 'Jupyter Notebook'},
#      {'short': True, 'title': 'Last updated', 'value': '8 minutes ago'}],
#     'id': 1,
#     'is_app_unfurl': True,
#     'title': 'AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu'}],
#   'blocks': [{'block_id': 'Tjy',
#     'elements': [{'elements': [{'text': 'Chào mọi người, mình  gửi Assignment 1 nhé:\n',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://github.com/AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '65967e82-ee13-4c5d-8cd8-8cfec7050f5e',
#   'edited': {'ts': '1619233440.000000', 'user': 'U01VB63LRNC'},
#   'is_locked': False,
#   'latest_reply': '1620736634.003100',
#   'reactions': [{'count': 1,
#     'name': 'white_check_mark',
#     'users': ['U01UMJ451V1']}],
#   'reply_count': 1,
#   'reply_users': ['U01UMJ451V1'],
#   'reply_users_count': 1,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Chào mọi người, mình  gửi Assignment 1 nhé:\n<https://github.com/AnhThuNguyenHuynh/datacracy-atom-NguyenHuynhAnhThu>',
#   'thread_ts': '1619229687.043200',
#   'ts': '1619229687.043200',
#   'type': 'message',
#   'user': 'U01VB63LRNC'},
#  {'blocks': [{'block_id': 'odZ',
#     'elements': [{'elements': [{'text': 'Chào mọi người, mình gửi assignment 1: ',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://docs.google.com/document/d/1AVJC1OZUGY9evNxJQzDhGaPxfBDTWd-Cj_dcu1bxRsQ/edit?usp=sharing'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '2616dfec-29bb-426d-8f4e-e425a288347d',
#   'is_locked': False,
#   'latest_reply': '1620785516.006900',
#   'reactions': [{'count': 1,
#     'name': 'white_check_mark',
#     'users': ['U01UTGRMGEQ']}],
#   'reply_count': 2,
#   'reply_users': ['U01UTGRMGEQ', 'U01UTGS5ZNY'],
#   'reply_users_count': 2,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Chào mọi người, mình gửi assignment 1: <https://docs.google.com/document/d/1AVJC1OZUGY9evNxJQzDhGaPxfBDTWd-Cj_dcu1bxRsQ/edit?usp=sharing>',
#   'thread_ts': '1619228672.042500',
#   'ts': '1619228672.042500',
#   'type': 'message',
#   'user': 'U01UTGS5ZNY'},
#  {'attachments': [{'app_unfurl_url': 'https://github.com/vietqh/datacracy-atom-HoangQuocViet',
#     'bot_id': 'B01UQU8E2A3',
#     'color': '24292f',
#     'fallback': 'vietqh/datacracy-atom-HoangQuocViet',
#     'fields': [{'short': True,
#       'title': 'Language',
#       'value': 'Jupyter Notebook'},
#      {'short': True, 'title': 'Last updated', 'value': '28 minutes ago'}],
#     'id': 1,
#     'is_app_unfurl': True,
#     'title': 'vietqh/datacracy-atom-HoangQuocViet'}],
#   'blocks': [{'block_id': 'EHA',
#     'elements': [{'elements': [{'text': 'Chào mọi người, mình gửi assignment 1: Task 1:\xa0',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://docs.google.com/spreadsheets/d/1O3sH0lT7hPcR2AWq9MYkGmbdnK1oNPgBgNdcHcaoQrU/edit#gid=1677392585'},
#        {'text': '\xa0\nTask 2:\xa0', 'type': 'text'},
#        {'type': 'link',
#         'url': 'https://colab.research.google.com/drive/1wmEYMAaGCw0OzSzOVLD9rwxvkk8gr4z5#scrollTo=2BGRX19L6fgb'},
#        {'text': '\xa0\nTask 3:\xa0', 'type': 'text'},
#        {'type': 'link',
#         'url': 'https://github.com/vietqh/datacracy-atom-HoangQuocViet'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '16a573fd-377c-4713-9045-818f1fe64ae4',
#   'is_locked': False,
#   'latest_reply': '1620991326.023600',
#   'reactions': [{'count': 2,
#     'name': 'construction',
#     'users': ['U01UTGS5ZNY', 'U01V00P4S2V']}],
#   'reply_count': 1,
#   'reply_users': ['U01V00P4S2V'],
#   'reply_users_count': 1,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': 'Chào mọi người, mình gửi assignment 1: Task 1:\xa0<https://docs.google.com/spreadsheets/d/1O3sH0lT7hPcR2AWq9MYkGmbdnK1oNPgBgNdcHcaoQrU/edit#gid=1677392585>\xa0\nTask 2:\xa0<https://colab.research.google.com/drive/1wmEYMAaGCw0OzSzOVLD9rwxvkk8gr4z5#scrollTo=2BGRX19L6fgb>\xa0\nTask 3:\xa0<https://github.com/vietqh/datacracy-atom-HoangQuocViet>',
#   'thread_ts': '1619226537.041400',
#   'ts': '1619226537.041400',
#   'type': 'message',
#   'user': 'U01U6JM6LEB'},
#  {'attachments': [{'fallback': 'Google Colaboratory',
#     'from_url': 'https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing',
#     'id': 1,
#     'image_bytes': 4534,
#     'image_height': 250,
#     'image_url': 'https://colab.research.google.com/img/colab_favicon_256px.png',
#     'image_width': 250,
#     'original_url': 'https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing',
#     'service_icon': 'https://colab.research.google.com/img/favicon.ico?vrz=colab-20210422-060049-RC00_369841174',
#     'service_name': 'colab.research.google.com',
#     'title': 'Google Colaboratory',
#     'title_link': 'https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing'}],
#   'blocks': [{'block_id': '5uv',
#     'elements': [{'elements': [{'text': 'Mình gửi bài assignment1:\nTask 1: ',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://docs.google.com/spreadsheets/d/1XDHiv72ITLoY1aGYuc1LbqpVq20k72th4XRYPmqSAhI/edit?usp=sharing'},
#        {'text': '\nTask 2: ', 'type': 'text'},
#        {'type': 'link',
#         'url': 'https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing'},
#        {'text': '\nTask 3: ', 'type': 'text'},
#        {'type': 'link',
#         'url': 'https://github.com/vuthanhdatt/datacracy-atom-VuThanhDat'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': 'e77725c4-cccc-4ea0-a0f3-d3f8a7f434e2',
#   'reactions': [{'count': 1,
#     'name': 'construction',
#     'users': ['U01UMBZHU2W']}],
#   'team': 'T01B7SGGMLJ',
#   'text': 'Mình gửi bài assignment1:\nTask 1: <https://docs.google.com/spreadsheets/d/1XDHiv72ITLoY1aGYuc1LbqpVq20k72th4XRYPmqSAhI/edit?usp=sharing>\nTask 2: <https://colab.research.google.com/drive/1VnMQdhpjKldwvJnjqpYO0sQkeaVbvNyB?usp=sharing>\nTask 3: <https://github.com/vuthanhdatt/datacracy-atom-VuThanhDat>',
#   'ts': '1619216201.038200',
#   'type': 'message',
#   'user': 'U01V00P4S2V'},
#  {'blocks': [{'block_id': 'Lhrv',
#     'elements': [{'elements': [{'text': 'Em xin gửi link Doc tổng hợp phần bài tập của em ạ\n',
#         'type': 'text'},
#        {'type': 'link',
#         'url': 'https://docs.google.com/document/d/1vf7hHma_ARS8lwPUam0bEv4K00wVo1pmCMH8YQ5fJTw/edit?usp=sharing'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': '130cb063-2355-4d69-8e98-e058ceeeca34',
#   'display_as_bot': False,
#   'files': [{'created': 1619207265,
#     'display_as_bot': False,
#     'editable': False,
#     'external_id': '1vf7hHma_ARS8lwPUam0bEv4K00wVo1pmCMH8YQ5fJTw',
#     'external_type': 'gdrive',
#     'external_url': 'https://docs.google.com/document/d/1vf7hHma_ARS8lwPUam0bEv4K00wVo1pmCMH8YQ5fJTw/edit?usp=sharing',
#     'filetype': 'gdoc',
#     'has_rich_preview': True,
#     'id': 'F0202TGEU5A',
#     'is_external': True,
#     'is_public': True,
#     'is_starred': False,
#     'mimetype': 'application/vnd.google-apps.document',
#     'mode': 'external',
#     'name': 'ATOM - HOMEWORK - Thiên Phú',
#     'original_h': 1035,
#     'original_w': 800,
#     'permalink': 'https://datacracy.slack.com/files/U01UMBX2X18/F0202TGEU5A/atom_-_homework_-_thi__n_ph__',
#     'pretty_type': 'G Suite Document',
#     'public_url_shared': False,
#     'size': 31265,
#     'thumb_1024': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0202TGEU5A-d167f29136/atom_-_homework_-_thi__n_ph___1024.png',
#     'thumb_1024_h': 1024,
#     'thumb_1024_w': 791,
#     'thumb_160': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0202TGEU5A-d167f29136/atom_-_homework_-_thi__n_ph___160.png',
#     'thumb_360': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0202TGEU5A-d167f29136/atom_-_homework_-_thi__n_ph___360.png',
#     'thumb_360_h': 360,
#     'thumb_360_w': 278,
#     'thumb_480': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0202TGEU5A-d167f29136/atom_-_homework_-_thi__n_ph___480.png',
#     'thumb_480_h': 480,
#     'thumb_480_w': 371,
#     'thumb_64': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0202TGEU5A-d167f29136/atom_-_homework_-_thi__n_ph___64.png',
#     'thumb_720': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0202TGEU5A-d167f29136/atom_-_homework_-_thi__n_ph___720.png',
#     'thumb_720_h': 720,
#     'thumb_720_w': 557,
#     'thumb_80': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F0202TGEU5A-d167f29136/atom_-_homework_-_thi__n_ph___80.png',
# ...
#        {'name': 'smiling_face_with_3_hearts', 'type': 'emoji'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': 'f37184b6-5b1d-4e2e-a0ef-72106846683c',
#   'is_locked': False,
#   'latest_reply': '1621129563.000800',
#   'reactions': [{'count': 7,
#     'name': '+1',
#     'users': ['U01V00LQ7EV',
#      'U01U6JQB695',
#      'U01UJ9MUADT',
#      'U01UEJFMUSJ',
#      'U01UJ9P1S3X',
#      'U01BE2PR6LU',
#      'U01UJ9PRT5K']},
#    {'count': 4,
#     'name': 'wave',
#     'users': ['U01UJ9M5TU5', 'U01UEJFMUSJ', 'U01BE2PR6LU', 'U01VB632FPS']},
#    {'count': 1, 'name': 'construction', 'users': ['U01UJ9PRT5K']},
#    {'count': 2,
#     'name': 'white_check_mark',
#     'users': ['U01V00JK9LH', 'U01UJ9PRT5K']}],
#   'reply_count': 2,
#   'reply_users': ['U01V00JK9LH', 'U01UJ9PRT5K'],
#   'reply_users_count': 2,
#   'subscribed': False,
#   'team': 'T01B7SGGMLJ',
#   'text': '<https://github.com/duongphannamhung/datacracy-atom-duongphannamhung> : Em gửi link assignment 1 của mình. Chúc mọi người nghỉ lễ vui vẻ nha :smiling_face_with_3_hearts:',
#   'thread_ts': '1618984834.000800',
#   'ts': '1618984834.000800',
#   'type': 'message',
#   'user': 'U01UMJ5AQ0K'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UMC0N5U2> has joined the channel',
#   'ts': '1618906057.000400',
#   'type': 'message',
#   'user': 'U01UMC0N5U2'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UJ9M3P1T> has joined the channel',
#   'ts': '1618889000.000200',
#   'type': 'message',
#   'user': 'U01UJ9M3P1T'},
#  {'subtype': 'channel_join',
#   'text': '<@U01V00KHHHP> has joined the channel',
#   'ts': '1618843802.000700',
#   'type': 'message',
#   'user': 'U01V00KHHHP'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UMBW8G8J> has joined the channel',
#   'ts': '1618840931.000500',
#   'type': 'message',
#   'user': 'U01UMBW8G8J'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UJ9M5TU5> has joined the channel',
#   'ts': '1618811202.000300',
#   'type': 'message',
#   'user': 'U01UJ9M5TU5'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UJ9P1S3X> has joined the channel',
#   'ts': '1618717697.000200',
#   'type': 'message',
#   'user': 'U01UJ9P1S3X'},
#  {'subtype': 'channel_join',
#   'text': '<@U01U6JQB695> has joined the channel',
#   'ts': '1618677920.001600',
#   'type': 'message',
#   'user': 'U01U6JQB695'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UMJ5AQ0K> has joined the channel',
#   'ts': '1618672178.001400',
#   'type': 'message',
#   'user': 'U01UMJ5AQ0K'},
#  {'subtype': 'channel_join',
#   'text': '<@U01V00LQ7EV> has joined the channel',
#   'ts': '1618669828.001200',
#   'type': 'message',
#   'user': 'U01V00LQ7EV'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UJ9MUADT> has joined the channel',
#   'ts': '1618667658.001000',
#   'type': 'message',
#   'user': 'U01UJ9MUADT'},
#  {'subtype': 'channel_join',
#   'text': '<@U01V082PLN5> has joined the channel',
#   'ts': '1618653541.000800',
#   'type': 'message',
#   'user': 'U01V082PLN5'},
#  {'subtype': 'channel_join',
#   'text': '<@U01V00JK9LH> has joined the channel',
#   'ts': '1618653422.000600',
#   'type': 'message',
#   'user': 'U01V00JK9LH'},
#  {'subtype': 'channel_join',
#   'text': '<@U01VB63LRNC> has joined the channel',
#   'ts': '1618652951.000400',
#   'type': 'message',
#   'user': 'U01VB63LRNC'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UTQ4AVRS> has joined the channel',
#   'ts': '1618652045.000200',
#   'type': 'message',
#   'user': 'U01UTQ4AVRS'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UJ9PRT5K> has joined the channel',
#   'ts': '1618649272.000200',
#   'type': 'message',
#   'user': 'U01UJ9PRT5K'},
#  {'subtype': 'channel_join',
#   'text': '<@U01UJ9LG5U5> has joined the channel',
#   'ts': '1618644757.001800',
#   'type': 'message',
#   'user': 'U01UJ9LG5U5'},
#  {'attachments': [{'author_icon': 'https://secure.gravatar.com/avatar/dcf7e1aca86cc2adb657e2bd2415352f.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2Fdf10d%2Fimg%2Favatars%2Fava_0025-48.png',
#     'author_id': 'U01BE2PR6LU',
#     'author_link': 'https://datacracy.slack.com/team/U01BE2PR6LU',
#     'author_name': 'Đặng Huỳnh Mai Anh',
#     'author_subname': 'Đặng Huỳnh Mai Anh',
#     'channel_id': 'C01UL6K1C7L',
#     'channel_name': 'atom-week1',
#     'fallback': '[April 17th, 2021 12:23 AM] maianhdang.ftu: *WEEK 1: DATA STRATEGY &amp; METRICS DESIGN*\n*----------*\nXin chào mọi người <!channel>,\n:white_check_mark: Các câu hỏi liên quan đến nội dung  *`WEEK 1`* mời mọi người trao đổi trong channel này nha <#C01UL6K1C7L|atom-week1>\n:white_check_mark: Các câu hỏi trong quá trình làm *`Lab1`* =&gt; <#C01UL6K1C7L|atom-week1>\n:red_circle: Các câu hỏi trong quá trình làm *`Assignment#1` =&gt; <#C01U6P7LZ8F|atom-assignment1>*\n\nNhư vậy chúng ta đã có Session đầu tiên để kick-off chuỗi ATOM classes.\n&gt; *RECAP NỘI DUNG*\n• <https://docs.google.com/presentation/d/1YRDjcK6as04WxGga0rPQMyd1AwJmL3ySFDfgVUCpGjs/edit#slide=id.gcf12cb55cb_0_0|Data Strategy> SLIDE: \n    ◦ Doanh Nghiệp (DN) nào cũng là một DN data\n    ◦ Data Solution có thể ở scale nhỏ, nhưng tạo ra giá trị lớn với kinh phí thấp\n    ◦ Chiến lược dữ liệu cần bắt đầu từ những câu hỏi lớn của DN\n    ◦ Để tìm ra câu hỏi, tập trung vào các mảng vận hành chính, câu hỏi trong mỗi mảng\n    ◦ Với mỗi câu hỏi, cần những metrics gì, và các methods phố biến có thể sử dụng\n• Principles of Metrics <https://app.gitbook.com/@anhdang/s/datacracy/atom/1-data-strategy-and-metrics/1.2-principles-of-metrics|LINK>: \n    ◦ Mọi thứ (dẫu có trừu tượng) đều có thể đo lường, bằng cách\n        ▪︎ Decomposition (Phân rã)\n        ▪︎ Clarification Chain: Chuỗi suy luận để định lượng hoá các vấn đề\n    ◦ Khi đã có các metrics ta sẽ chọn lựa bằng Information Value\n        ▪︎ Theo cách đánh giá từ phía business\n        ▪︎ Nguyên tắc là: Chọn các metrics covers nhiều mảng khác nhau (nội dung của metrics không trùng lặp). Nếu có nhiều metrics cùng đo lường một vấn đề (highly-correlated với nhau), thì chọn metrics nào dễ và thuận lời đo lường nhất.\n        ▪︎ Ngoài ra có nhiều phương pháp khác (Các bạn có thể google thêm Information Value) =&gt; Nội dung này sẽ nằm trong các buổi sau\n    ◦ Đọc thêm về cách đo lường Hạnh Phúc <https://app.gitbook.com/@anhdang/s/datacracy/big-o/2-everyone-can-read-data/dataviz-and-storytelling#hanh-phuc|HERE>\n&gt; *LAB#1: SPREADSHEET*\n• Step-by-step hướng dẫn: <https://docs.google.com/spreadsheets/d/1Cu3filZ18vCjXGRzElpi9jjDYupV3r9hGMlbcMff9R4/edit?usp=sharing|Lab#1: Analytics on Spreadsheet>\n• Solution <https://app.gitbook.com/@anhdang/s/datacracy/atom/1-data-strategy-and-metrics/1.3-lab-analytics-on-spreadsheet|HERE>\n&gt; *HOME ASSIGNMENT#1*\n• <https://app.gitbook.com/@anhdang/s/datacracy/atom/1-data-strategy-and-metrics/1.4-home-assignment|Home Assignment#1>, gồm: Google Spreadsheet Analytics, Google Colab + Python Programming, Github repo\n• Sách tham khảo cho Python Programming: Sweigart 2019 - Automate Boring Stuff with Python for Total Beginner (Đính kèm trong message này)\n• Mọi người post assignment của mình vào <#C01U6P7LZ8F|atom-assignment1> (trước buổi học :calendar: Week 2, thứ 7, ngày 24/04)\n    ◦ Vì nội dung có tính sáng tạo riêng nên chúng ta cùng chia sẻ công khai và tin rằng mỗi bài sẽ tiếp cận mỗi khác nhé',
#     'files': [{'created': 1618643762,
#       'display_as_bot': False,
#       'editable': False,
#       'external_type': '',
#       'filetype': 'pdf',
#       'has_rich_preview': False,
#       'id': 'F01UJEL9UKX',
#       'is_external': False,
#       'is_public': True,
#       'mimetype': 'application/pdf',
#       'mode': 'hosted',
#       'name': 'Sweigart 2019 Automate the Boring Stuff with Python Practical Programming for Total Beginners (2nd edition).pdf',
#       'permalink': 'https://datacracy.slack.com/files/U01BE2PR6LU/F01UJEL9UKX/sweigart_2019_automate_the_boring_stuff_with_python_practical_programming_for_total_beginners__2nd_edition_.pdf',
#       'permalink_public': 'https://slack-files.com/T01B7SGGMLJ-F01UJEL9UKX-e66288fe59',
#       'pretty_type': 'PDF',
#       'public_url_shared': False,
#       'size': 14894528,
#       'thumb_pdf': 'https://files.slack.com/files-tmb/T01B7SGGMLJ-F01UJEL9UKX-3dd891e55a/sweigart_2019_automate_the_boring_stuff_with_python_practical_programming_for_total_beginners__2nd_edition__thumb_pdf.png',
#       'thumb_pdf_h': 1210,
#       'thumb_pdf_w': 935,
#       'timestamp': 1618643762,
#       'title': 'Sweigart 2019 Automate the Boring Stuff with Python Practical Programming for Total Beginners (2nd edition).pdf',
#       'url_private': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F01UJEL9UKX/sweigart_2019_automate_the_boring_stuff_with_python_practical_programming_for_total_beginners__2nd_edition_.pdf',
#       'url_private_download': 'https://files.slack.com/files-pri/T01B7SGGMLJ-F01UJEL9UKX/download/sweigart_2019_automate_the_boring_stuff_with_python_practical_programming_for_total_beginners__2nd_edition_.pdf',
#       'user': 'U01BE2PR6LU',
#       'username': ''}],
#     'footer': 'Posted in #atom-week1',
#     'from_url': 'https://datacracy.slack.com/archives/C01UL6K1C7L/p1618644200017500',
#     'id': 1,
#     'is_msg_unfurl': True,
#     'mrkdwn_in': ['text'],
#     'original_url': 'https://datacracy.slack.com/archives/C01UL6K1C7L/p1618644200017500',
#     'text': '*WEEK 1: DATA STRATEGY &amp; METRICS DESIGN*\n*----------*\nXin chào mọi người <!channel>,\n:white_check_mark: Các câu hỏi liên quan đến nội dung  *`WEEK 1`* mời mọi người trao đổi trong channel này nha <#C01UL6K1C7L|atom-week1>\n:white_check_mark: Các câu hỏi trong quá trình làm *`Lab1`* =&gt; <#C01UL6K1C7L|atom-week1>\n:red_circle: Các câu hỏi trong quá trình làm *`Assignment#1` =&gt; <#C01U6P7LZ8F|atom-assignment1>*\n\nNhư vậy chúng ta đã có Session đầu tiên để kick-off chuỗi ATOM classes.\n&gt; *RECAP NỘI DUNG*\n• <https://docs.google.com/presentation/d/1YRDjcK6as04WxGga0rPQMyd1AwJmL3ySFDfgVUCpGjs/edit#slide=id.gcf12cb55cb_0_0|Data Strategy> SLIDE: \n    ◦ Doanh Nghiệp (DN) nào cũng là một DN data\n    ◦ Data Solution có thể ở scale nhỏ, nhưng tạo ra giá trị lớn với kinh phí thấp\n    ◦ Chiến lược dữ liệu cần bắt đầu từ những câu hỏi lớn của DN\n    ◦ Để tìm ra câu hỏi, tập trung vào các mảng vận hành chính, câu hỏi trong mỗi mảng\n    ◦ Với mỗi câu hỏi, cần những metrics gì, và các methods phố biến có thể sử dụng\n• Principles of Metrics <https://app.gitbook.com/@anhdang/s/datacracy/atom/1-data-strategy-and-metrics/1.2-principles-of-metrics|LINK>: \n    ◦ Mọi thứ (dẫu có trừu tượng) đều có thể đo lường, bằng cách\n        ▪︎ Decomposition (Phân rã)\n        ▪︎ Clarification Chain: Chuỗi suy luận để định lượng hoá các vấn đề\n    ◦ Khi đã có các metrics ta sẽ chọn lựa bằng Information Value\n        ▪︎ Theo cách đánh giá từ phía business\n        ▪︎ Nguyên tắc là: Chọn các metrics covers nhiều mảng khác nhau (nội dung của metrics không trùng lặp). Nếu có nhiều metrics cùng đo lường một vấn đề (highly-correlated với nhau), thì chọn metrics nào dễ và thuận lời đo lường nhất.\n        ▪︎ Ngoài ra có nhiều phương pháp khác (Các bạn có thể google thêm Information Value) =&gt; Nội dung này sẽ nằm trong các buổi sau\n    ◦ Đọc thêm về cách đo lường Hạnh Phúc <https://app.gitbook.com/@anhdang/s/datacracy/big-o/2-everyone-can-read-data/dataviz-and-storytelling#hanh-phuc|HERE>\n&gt; *LAB#1: SPREADSHEET*\n• Step-by-step hướng dẫn: <https://docs.google.com/spreadsheets/d/1Cu3filZ18vCjXGRzElpi9jjDYupV3r9hGMlbcMff9R4/edit?usp=sharing|Lab#1: Analytics on Spreadsheet>\n• Solution <https://app.gitbook.com/@anhdang/s/datacracy/atom/1-data-strategy-and-metrics/1.3-lab-analytics-on-spreadsheet|HERE>\n&gt; *HOME ASSIGNMENT#1*\n• <https://app.gitbook.com/@anhdang/s/datacracy/atom/1-data-strategy-and-metrics/1.4-home-assignment|Home Assignment#1>, gồm: Google Spreadsheet Analytics, Google Colab + Python Programming, Github repo\n• Sách tham khảo cho Python Programming: Sweigart 2019 - Automate Boring Stuff with Python for Total Beginner (Đính kèm trong message này)\n• Mọi người post assignment của mình vào <#C01U6P7LZ8F|atom-assignment1> (trước buổi học :calendar: Week 2, thứ 7, ngày 24/04)\n    ◦ Vì nội dung có tính sáng tạo riêng nên chúng ta cùng chia sẻ công khai và tin rằng mỗi bài sẽ tiếp cận mỗi khác nhé',
#     'ts': '1618644200.017500'}],
#   'blocks': [{'block_id': 'ajSH',
#     'elements': [{'elements': [{'style': {'bold': True},
#         'text': 'HOME ASSIGNMENT#1',
#         'type': 'text'}],
#       'type': 'rich_text_quote'},
#      {'elements': [{'name': 'red_circle',
#         'style': {'bold': True},
#         'type': 'emoji'},
#        {'style': {'bold': True},
#         'text': ' Channel để trao đổi & giai đáp thắc mắc trong quá trình làm Assignmetn#1',
#         'type': 'text'},
#        {'text': '\n', 'type': 'text'},
#        {'name': 'raised_hands', 'style': {'bold': True}, 'type': 'emoji'},
#        {'style': {'bold': True},
#         'text': ' Ai đã thấy tin nhắn, hãy react cho vui nhà vui của nhé',
#         'type': 'text'},
#        {'text': '\n', 'type': 'text'}],
#       'type': 'rich_text_section'},
#      {'elements': [{'elements': [{'text': 'Home Assignment#1',
#           'type': 'link',
#           'url': 'https://app.gitbook.com/@anhdang/s/datacracy/atom/1-data-strategy-and-metrics/1.4-home-assignment'},
#          {'text': ', gồm: Google Spreadsheet Analytics, Google Colab + Python Programming, Github repo',
#           'type': 'text'}],
#         'type': 'rich_text_section'},
#        {'elements': [{'text': 'Sách tham khảo cho Python Programming: Sweigart 2019 - Automate Boring Stuff with Python for Total Beginner (Đính kèm trong message này)',
#           'type': 'text'}],
#         'type': 'rich_text_section'},
#        {'elements': [{'text': 'Mọi người post assignment của mình vào\xa0',
#           'type': 'text'},
#          {'channel_id': 'C01U6P7LZ8F', 'type': 'channel'},
#          {'text': '\xa0(trước buổi học\xa0', 'type': 'text'},
#          {'name': 'calendar', 'type': 'emoji'},
#          {'text': '\xa0Week 2, thứ 7, ngày 24/04)', 'type': 'text'}],
#         'type': 'rich_text_section'}],
#       'indent': 0,
#       'style': 'bullet',
#       'type': 'rich_text_list'},
#      {'elements': [{'elements': [{'text': 'Vì nội dung có tính sáng tạo riêng nên chúng ta cùng chia sẻ công khai và tin rằng mỗi bài sẽ tiếp cận mỗi khác nhé',
#           'type': 'text'}],
#         'type': 'rich_text_section'}],
#       'indent': 1,
#       'style': 'bullet',
#       'type': 'rich_text_list'},
#      {'elements': [{'type': 'link',
#         'url': 'https://datacracy.slack.com/archives/C01UL6K1C7L/p1618644200017500'}],
#       'type': 'rich_text_section'}],
#     'type': 'rich_text'}],
#   'client_msg_id': 'ee293aa9-a2c1-4db3-a119-7233519a5b21',
#   'edited': {'ts': '1618644481.000000', 'user': 'U01BE2PR6LU'},
#   'pinned_info': {'channel': 'C01U6P7LZ8F',
#    'pinned_by': 'U01BE2PR6LU',
#    'pinned_ts': 1618644558},
#   'pinned_to': ['C01U6P7LZ8F'],
#   'reactions': [{'count': 3,
#     'name': 'raised_hands',
#     'users': ['U01BE2PR6LU', 'U01UJ9PRT5K', 'U01UJ9P1S3X']},
#    {'count': 1, 'name': 'dart', 'users': ['U01UMJ5AQ0K']}],
#   'team': 'T01B7SGGMLJ',
#   'text': '&gt; *HOME ASSIGNMENT#1*\n:red_circle: *Channel để trao đổi &amp; giai đáp thắc mắc trong quá trình làm Assignmetn#1*\n:raised_hands: *Ai đã thấy tin nhắn, hãy react cho vui nhà vui của nhé*\n• <https://app.gitbook.com/@anhdang/s/datacracy/atom/1-data-strategy-and-metrics/1.4-home-assignment|Home Assignment#1>, gồm: Google Spreadsheet Analytics, Google Colab + Python Programming, Github repo\n• Sách tham khảo cho Python Programming: Sweigart 2019 - Automate Boring Stuff with Python for Total Beginner (Đính kèm trong message này)\n• Mọi người post assignment của mình vào\xa0<#C01U6P7LZ8F|atom-assignment1>\xa0(trước buổi học\xa0:calendar:\xa0Week 2, thứ 7, ngày 24/04)\n    ◦ Vì nội dung có tính sáng tạo riêng nên chúng ta cùng chia sẻ công khai và tin rằng mỗi bài sẽ tiếp cận mỗi khác nhé\n<https://datacracy.slack.com/archives/C01UL6K1C7L/p1618644200017500>',
#   'ts': '1618644250.000900',
#   'type': 'message',
#   'user': 'U01BE2PR6LU'},
#  {'subtype': 'channel_join',
#   'text': '<@U01BE2PR6LU> has joined the channel',
#   'ts': '1618642805.000200',
#   'type': 'message',
#   'user': 'U01BE2PR6LU'}]

# %%
dict_as2 = {'ts':[], 'user':[], 'reply_count':[],'reply_users':[],'latest_reply':[],'github':[]} #Liệt kê các keys
not_learners_id = ['U01BE2PR6LU'] # -> Remove MA from the user_id
# user_dict_as2

# %%
github, reply_count, reply_users_count, reply_users, latest_reply = '','','','',''
for i in range(len(msg_as2)):
  ts = dt.fromtimestamp(float(msg_as2[i]['ts'])) # -> Convert timestamp Epoch thành dàng dễ đọc
  user = msg_as2[i]['user'] # -> Lấy thông tin người post messages
  if msg_as2[i]['user'] not in not_learners_id:
    if 'attachments' in msg_as2[i].keys():
      # print(msg_as2[i].keys())
      text = msg_as2[i]['text']
      github_link = re.findall('(?:https?://)?(?:www[.])?github[.]com/[\w-]+/?', text) #-> Submission là các message có link github
      #print(msg_as2[i])
      if len(github_link) > 0: github = github_link[0]
      if 'user' in msg_as2[i].keys():  user_dict_as2['user'].append(msg_as2[i]['user'])
      else:  user_dict_as2['user'].append('No data')
      if 'reply_count' in msg_as2[i].keys():  user_dict_as2['reply_count'].append(msg_as2[i]['reply_count'])#-> Extract số review 
      else: user_dict_as2['reply_count'].append('No data')
      if 'reply_users' in msg_as2[i].keys(): user_dict_as2['reply_users'].append(msg_as2[i]['reply_users'])
      else: user_dict_as2['reply_users'].append('No data')
      if 'latest_reply' in msg_as2[i].keys(): user_dict_as2['latest_reply'].append(msg_as2[i]['latest_reply'])
      else: user_dict_as2['latest_reply'].append('No data')
      print(ts, user, reply_users_count, reply_users, latest_reply, github)
# Out:
# 2021-05-10 04:51:46.004700 U01UJ9LG5U5    https://github.com/danhpcv/
# 2021-05-10 04:35:39.003800 U01UMC08KL2    https://github.com/auslynnguyen/
# 2021-05-08 06:31:59.005200 U01UMJ36QD9    https://github.com/auslynnguyen/
# 2021-05-04 13:55:46.001800 U01UTGVPE7N    https://github.com/hoaintp/
# 2021-05-03 17:41:18.002400 U01U6JQB695    https://github.com/Tenderriver/
# 2021-05-03 08:51:19.001200 U01V00KHHHP    https://github.com/saturn1101/
# 2021-04-26 06:53:56.000800 U01UMBZHU2W    https://github.com/saturn1101/
# 2021-04-24 02:01:27.043200 U01VB63LRNC    https://github.com/AnhThuNguyenHuynh/
# 2021-04-24 01:08:57.041400 U01U6JM6LEB    https://github.com/vietqh/
# 2021-04-23 22:16:41.038200 U01V00P4S2V    https://github.com/vuthanhdatt/
# 2021-04-23 18:56:58.034700 U01UTGRP0HJ    https://github.com/TranPham-96/
# 2021-04-23 16:45:14.029300 U01UMJ451V1    https://github.com/annaho124/
# 2021-04-23 16:41:53.026200 U01UJ9M5TU5    https://github.com/minhnguyentk95/
# 2021-04-23 15:48:06.023900 U01UJ9NKX8D    https://github.com/lienanh264/
# 2021-04-23 15:03:37.023200 U01UJ9MUADT    https://github.com/Lulichlam/
# 2021-04-23 14:49:19.022500 U01VB6AT4G0    https://github.com/tamle1012/
# 2021-04-23 11:44:48.011300 U01UJ9LG5U5    https://github.com/danhpcv/
# 2021-04-23 09:23:49.008700 U01UTGT8CVA    https://github.com/ngttnguyen/
# 2021-04-23 07:38:25.004100 U01UJ9M3P1T    https://github.com/cnhhoang850/
# 2021-04-23 01:47:56.001500 U01UJ9PA0MB    https://github.com/cnhhoang850/
# 2021-04-22 16:50:07.003300 U01V082PLN5    https://github.com/interphuoc/
# 2021-04-21 06:00:34.000800 U01UMJ5AQ0K    https://github.com/duongphannamhung/

# %%
len(user_dict_as2['user'])
# Out:
# 154

# %%
as2_df = pd.DataFrame(user_dict_as2) ## Dùng pandas để convert dictionaries thành bảng
# as2.head(5) ## Chỉ in 5 dòng đầu (chủ yếu để xem cấu trúc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-435c4f041d1d> in <module>()
# ----> 1 as2_df = pd.DataFrame(user_dict_as2) ## Dùng pandas để convert dictionaries thành bảng
#       2 # as2.head(5) ## Chỉ in 5 dòng đầu (chủ yếu để xem cấu trúc)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
# ACCES GOOGLE SHEET
sheet_index_no = 0
spreadsheet_key = '164_OwrRR10m5N5-avjMn1fBZhgBq6qNpFA6ay0uZuY8' # input SPREADSHEET_KEY HERE
sh = gc.open_by_key(spreadsheet_key)
worksheet = sh.get_worksheet(sheet_index_no) #-> 0 - first sheet, 1 - second sheet etc. 

# APPEND DATA TO SHEET
set_with_dataframe(worksheet, user_df) #-> Upload user_df vào Sheet đầu tiên trong Spreadsheet

# DONE: Bây giờ bạn có thể mở spreadsheet và kiểm tra nội dung đã update chứ
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-157-09335c6adf79> in <module>()
#       3 spreadsheet_key = '164_OwrRR10m5N5-avjMn1fBZhgBq6qNpFA6ay0uZuY8' # input SPREADSHEET_KEY HERE
#       4 sh = gc.open_by_key(spreadsheet_key)
# ----> 5 worksheet = sh.get_worksheet(sheet_index_no) #-> 0 - first sheet, 1 - second sheet etc.
#       6
#       7 # APPEND DATA TO SHEET
#
# /usr/local/lib/python3.7/dist-packages/gspread/models.py in get_worksheet(self, index)
#     139
#     140         """
# --> 141         sheet_data = self.fetch_sheet_metadata()
#     142
#     143         try:
#
# /usr/local/lib/python3.7/dist-packages/gspread/models.py in fetch_sheet_metadata(self)
#     121         url = SPREADSHEET_URL % self.id
#     122
# --> 123         r = self.client.request('get', url, params=params)
#     124
#     125         return r.json()
#
# /usr/local/lib/python3.7/dist-packages/gspread/client.py in request(self, method, endpoint, params, data, json, files, headers)
#      77             return response
#      78         else:
# ---> 79             raise APIError(response)
#      80
#      81     def list_spreadsheet_files(self):
#
# APIError: {
#   "error": {
#     "code": 401,
#     "message": "Request had invalid authentication credentials. Expected OAuth 2 access token, login cookie or other valid authentication credential. See https://developers.google.com/identity/sign-in/web/devconsole-project.",
#     "status": "UNAUTHENTICATED",
#     "details": [
#       {
#         "@type": "type.googleapis.com/google.rpc.ErrorInfo",
#         "reason": "ACCESS_TOKEN_EXPIRED",
#         "domain": "googleapis.com",
#         "metadata": {
#           "service": "sheets.googleapis.com",
#           "method": "google.apps.sheets.v4.SpreadsheetsService.GetSpreadsheet"
#         }
#       }
#     ]
#   }
# }

# %% [markdown]
# -------------- HẾT PHẦN OPTION 2 ---------------------
